# %% [markdown]
# # Frequent Patterns & Association Rules

# %%
# %matplotlib inline

import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

from collections import defaultdict
from scipy.stats.stats import pearsonr

# %%
import fim
from fim import apriori

# %%
df = pd.read_csv("hr_COMMA_SEP.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
df2 = df.copy()

# %%
satisfaction_levels = ['Molto insoddisfatto', 'Insoddisfatto', 'Neutrale', 'Soddisfatto', 'Molto soddisfatto'] #5 bins
bins_sl = [0, 0.2, 0.4, 0.6, 0.8, 1.01]
df2['satisfaction_level_cat'] = pd.cut(df2['satisfaction_level'], bins=bins_sl, 
                         right=False, labels=satisfaction_levels)

# %%
#last_evaluation_levels = ['Molto negativa', 'Negativa', 'Neutrale', 'Positiva', 'Molto positiva'] #5 bins
#bins_le = [0, 0.2, 0.4, 0.6, 0.8, 1.01]
#df2['last_evaluation_cat'] = pd.cut(df2['last_evaluation'], bins=bins_le, 
#                        right=False, labels=last_evaluation_levels)

# %%
last_evaluation_levels = ['Insufficiente', 'Sufficiente', 'Discreto', 'Buono', 'Ottimo'] #5 bins
bins_le = [0.36, 0.56, 0.66, 0.76, 0.91, 1.01]
df2['last_evaluation_cat'] = pd.cut(df2['last_evaluation'], bins=bins_le, 
                         right=False, labels=last_evaluation_levels)

# %%
#number_project_labels = ['2/3', '4/5', '6/7'] #3 bins
#bins_np = [2, 4, 6, 8]
#df2['number_project_cat'] = pd.cut(df2['number_project'], bins=bins_np,
#                        right=False, labels=number_project_labels)

# %%
#average_monthly_hours_groups = ['96-138', '139-182', '183-225', '226-269', '270-310'] #5 bins
#bins_amh = [96, 139, 183, 226, 270, 311]
#df2['avg_monthly_hours_cat'] = pd.cut(df2['average_montly_hours'], bins=bins_amh,
#                         right=False, labels=average_monthly_hours_groups)

# %%
average_monthly_hours_groups = ['96-118', '119-140', '141-162', '163-184', '185-206',
                                '207-228', '229-250', '251-272', '273-294', '295-310'] #10 bins

bins_amh = [96, 119, 141, 163, 185, 207, 229, 251, 273, 295, 311]

df2['avg_monthly_hours_cat'] = pd.cut(df2['average_montly_hours'], bins=bins_amh,
                         right=False, labels=average_monthly_hours_groups)

# %%
#time_spend_company_labels = ['2/3/4', '5/6/7', '8/9/10'] #3 bins
#bins_tsc = [2, 5, 8, 11]
#df2['time_spend_company_cat'] = pd.cut(df2['time_spend_company'], bins = bins_tsc,
#                       right=False, labels=time_spend_company_labels)

# %%
df2.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary satisfaction_level_cat last_evaluation_cat avg_monthly_hours_cat
# 0     low          Insoddisfatto       Insufficiente               141-162
# 1  medium      Molto soddisfatto               Buono               251-272
# 2  medium    Molto insoddisfatto               Buono               251-272
# 3     low            Soddisfatto               Buono               207-228
# 4     low          Insoddisfatto       Insufficiente               141-162

# %%
df2.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales salary satisfaction_level_cat  \
# 14994                      0  support    low               Neutrale
# 14995                      0  support    low          Insoddisfatto
# 14996                      0  support    low          Insoddisfatto
# 14997                      0  support    low    Molto insoddisfatto
# 14998                      0  support    low          Insoddisfatto
#
#       last_evaluation_cat avg_monthly_hours_cat
# 14994         Sufficiente               141-162
# 14995       Insufficiente               141-162
# 14996       Insufficiente               141-162
# 14997              Ottimo               273-294
# 14998       Insufficiente               141-162

# %%
df2.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# 25%              156.000000            3.000000       0.000000      0.000000
# 50%              200.000000            3.000000       0.000000      0.000000
# 75%              245.000000            4.000000       0.000000      0.000000
# max              310.000000           10.000000       1.000000      1.000000
#
#        promotion_last_5years
# count           14999.000000
# mean                0.021268
# std                 0.144281
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                 0.000000
# max                 1.000000

# %%
df2.drop(['satisfaction_level', 'last_evaluation', 'average_montly_hours'], axis=1, inplace=True)
df2 = df2[['satisfaction_level_cat', 'last_evaluation_cat', 'number_project', 'avg_monthly_hours_cat', 'time_spend_company', 'Work_accident', 'left', 'promotion_last_5years', 'sales', 'salary']]
df2.head()
# Out:
#   satisfaction_level_cat last_evaluation_cat  number_project  \
# 0          Insoddisfatto       Insufficiente               2
# 1      Molto soddisfatto               Buono               5
# 2    Molto insoddisfatto               Buono               7
# 3            Soddisfatto               Buono               5
# 4          Insoddisfatto       Insufficiente               2
#
#   avg_monthly_hours_cat  time_spend_company  Work_accident  left  \
# 0               141-162                   3              0     1
# 1               251-272                   6              0     1
# 2               251-272                   4              0     1
# 3               207-228                   5              0     1
# 4               141-162                   3              0     1
#
#    promotion_last_5years  sales  salary
# 0                      0  sales     low
# 1                      0  sales  medium
# 2                      0  sales  medium
# 3                      0  sales     low
# 4                      0  sales     low

# %%
#df3 = df2.copy()
#df3['satisfaction_level_cat'] = df2['satisfaction_level_cat'].astype(str) + '_SAT'
#df3['last_evaluation_cat'] = df2['last_evaluation_cat'].astype(str) + '_LE'
#df3['number_project_cat'] = df2['number_project_cat'].astype(str) + '_NP'
#df3['avg_monthly_hours_cat'] = df2['avg_monthly_hours_cat'].astype(str) + '_AMH'
#df3['time_spend_company_cat'] = df2['time_spend_company_cat'].astype(str) + '_TSC'
#df3['Work_accident'] = df2['Work_accident'].astype(str) + '_WA'
#df3['left'] = df2['left'].astype(str) + '_L'
#df3['promotion_last_5years'] = df2['promotion_last_5years'].astype(str) + '_P'
#df3['sales'] = df2['sales'].astype(str) + '_D'
#df3['salary'] = df2['salary'].astype(str) + '_SA'

# %%
df3 = df2.copy()
df3['satisfaction_level_cat'] = df2['satisfaction_level_cat'].astype(str) + '_SAT'
df3['last_evaluation_cat'] = df2['last_evaluation_cat'].astype(str) + '_LE'
df3['number_project'] = df2['number_project'].astype(str) + '_NP'
df3['avg_monthly_hours_cat'] = df2['avg_monthly_hours_cat'].astype(str) + '_AMH'
df3['time_spend_company'] = df2['time_spend_company'].astype(str) + '_TSC'
df3['Work_accident'] = df2['Work_accident'].astype(str) + '_WA'
df3['left'] = df2['left'].astype(str) + '_L'
df3['promotion_last_5years'] = df2['promotion_last_5years'].astype(str) + '_P'
df3['sales'] = df2['sales'].astype(str) + '_D'
df3['salary'] = df2['salary'].astype(str) + '_SA'

# %%
df3.head()
# Out:
#     satisfaction_level_cat last_evaluation_cat number_project  \
# 0        Insoddisfatto_SAT    Insufficiente_LE           2_NP
# 1    Molto soddisfatto_SAT            Buono_LE           5_NP
# 2  Molto insoddisfatto_SAT            Buono_LE           7_NP
# 3          Soddisfatto_SAT            Buono_LE           5_NP
# 4        Insoddisfatto_SAT    Insufficiente_LE           2_NP
#
#   avg_monthly_hours_cat time_spend_company Work_accident left  \
# 0           141-162_AMH              3_TSC          0_WA  1_L
# 1           251-272_AMH              6_TSC          0_WA  1_L
# 2           251-272_AMH              4_TSC          0_WA  1_L
# 3           207-228_AMH              5_TSC          0_WA  1_L
# 4           141-162_AMH              3_TSC          0_WA  1_L
#
#   promotion_last_5years    sales     salary
# 0                   0_P  sales_D     low_SA
# 1                   0_P  sales_D  medium_SA
# 2                   0_P  sales_D  medium_SA
# 3                   0_P  sales_D     low_SA
# 4                   0_P  sales_D     low_SA

# %%
df3.describe()
# Out:
#        satisfaction_level_cat last_evaluation_cat number_project  \
# count                   14999               14999          14999
# unique                      5                   5              6
# top           Soddisfatto_SAT            Buono_LE           4_NP
# freq                     4239                3999           4365
#
#        avg_monthly_hours_cat time_spend_company Work_accident   left  \
# count                  14999              14999         14999  14999
# unique                    10                  8             2      2
# top              141-162_AMH              3_TSC          0_WA    0_L
# freq                    2667               6443         12830  11428
#
#        promotion_last_5years    sales  salary
# count                  14999    14999   14999
# unique                     2       10       3
# top                      0_P  sales_D  low_SA
# freq                   14680     4140    7316

# %%
df3.to_csv('hr_for_patterns.csv', sep=',', header=True)

# %%
hr_baskets_list = list()
for row in df3.values:
    hr_baskets_list.append(list(row))

# %%
#hr_baskets_list

# %%
len(hr_baskets_list)
# Out:
# 14999

# %%
#help(apriori)

# %% [markdown]
# # Patterns

# %%
frequent_patterns = apriori(hr_baskets_list, supp=10, zmin=3, target = 's')

# %%
len(frequent_patterns)
# Out:
# 189

# %%
frequent_patterns.sort(key=lambda pattern: pattern[1], reverse=True)
frequent_patterns
# Out:
# [(('0_L', '0_WA', '0_P'), 9200),
#  (('low_SA', '0_WA', '0_P'), 6228),
#  (('3_TSC', '0_WA', '0_P'), 5446),
#  (('medium_SA', '0_WA', '0_P'), 5371),
#  (('low_SA', '0_L', '0_P'), 5092),
#  (('medium_SA', '0_L', '0_P'), 4953),
#  (('3_TSC', '0_L', '0_P'), 4738),
#  (('medium_SA', '0_L', '0_WA'), 4266),
#  (('low_SA', '0_L', '0_WA'), 4199),
#  (('low_SA', '0_L', '0_WA', '0_P'), 4162),
#  (('medium_SA', '0_L', '0_WA', '0_P'), 4132),
#  (('3_TSC', '0_L', '0_WA'), 4036),
#  (('3_TSC', '0_L', '0_WA', '0_P'), 3946),
#  (('3_NP', '0_L', '0_P'), 3888),
#  (('4_NP', '0_L', '0_P'), 3843),
#  (('Soddisfatto_SAT', '0_L', '0_P'), 3750),
#  (('4_NP', '0_WA', '0_P'), 3590),
#  (('Molto soddisfatto_SAT', '0_L', '0_P'), 3549),
#  (('Molto soddisfatto_SAT', '0_WA', '0_P'), 3483),
#  (('sales_D', '0_WA', '0_P'), 3482),
#  (('Soddisfatto_SAT', '0_WA', '0_P'), 3459),
#  (('Buono_LE', '0_WA', '0_P'), 3389),
#  (('1_L', '0_WA', '0_P'), 3387),
#  (('4_NP', '0_L', '0_WA'), 3300),
#  (('3_NP', '0_L', '0_WA'), 3274),
#  (('3_NP', '0_WA', '0_P'), 3271),
#  (('4_NP', '0_L', '0_WA', '0_P'), 3211),
#  (('3_NP', '0_L', '0_WA', '0_P'), 3200),
#  (('3_TSC', 'low_SA', '0_P'), 3173),
#  (('Soddisfatto_SAT', '0_L', '0_WA'), 3142),
#  (('2_TSC', '0_L', '0_P'), 3137),
#  (('Insufficiente_LE', '0_WA', '0_P'), 3080),
#  (('Soddisfatto_SAT', '0_L', '0_WA', '0_P'), 3077),
#  (('Neutrale_SAT', '0_WA', '0_P'), 3066),
#  (('sales_D', '0_L', '0_P'), 3033),
#  (('Molto soddisfatto_SAT', '0_L', '0_WA'), 3021),
#  (('Molto soddisfatto_SAT', '0_L', '0_WA', '0_P'), 2940),
#  (('Buono_LE', '0_L', '0_P'), 2930),
#  (('3_TSC', 'low_SA', '0_WA'), 2784),
#  (('3_TSC', 'low_SA', '0_WA', '0_P'), 2763),
#  (('2_TSC', '0_WA', '0_P'), 2642),
#  (('3_TSC', 'medium_SA', '0_P'), 2639),
#  (('2_TSC', '0_L', '0_WA'), 2634),
#  (('2_TSC', '0_L', '0_WA', '0_P'), 2590),
#  (('sales_D', '0_L', '0_WA'), 2585),
#  (('sales_D', '0_L', '0_WA', '0_P'), 2517),
#  (('Neutrale_SAT', '0_L', '0_P'), 2512),
#  (('Buono_LE', '0_L', '0_WA'), 2494),
#  (('Buono_LE', '0_L', '0_WA', '0_P'), 2447),
#  (('3_TSC', 'medium_SA', '0_WA'), 2327),
#  (('technical_D', '0_WA', '0_P'), 2316),
#  (('5_NP', '0_WA', '0_P'), 2303),
#  (('Ottimo_LE', '0_WA', '0_P'), 2274),
#  (('3_TSC', 'medium_SA', '0_WA', '0_P'), 2265),
#  (('141-162_AMH', '0_WA', '0_P'), 2245),
#  (('3_TSC', 'low_SA', '0_L'), 2219),
#  (('4_TSC', '0_WA', '0_P'), 2213),
#  (('Insufficiente_LE', '0_L', '0_P'), 2202),
#  (('Insufficiente_LE', '3_TSC', '0_P'), 2201),
#  (('3_TSC', 'low_SA', '0_L', '0_P'), 2198),
#  (('3_TSC', 'medium_SA', '0_L'), 2164),
#  (('1_L', 'low_SA', '0_P'), 2158),
#  (('Neutrale_SAT', '0_L', '0_WA'), 2155),
#  (('2_NP', '0_WA', '0_P'), 2144),
#  (('Sufficiente_LE', '0_L', '0_P'), 2138),
#  (('Discreto_LE', '0_L', '0_P'), 2110),
#  (('Neutrale_SAT', '0_L', '0_WA', '0_P'), 2101),
#  (('5_NP', '0_L', '0_P'), 2099),
#  (('3_TSC', 'medium_SA', '0_L', '0_P'), 2089),
#  (('sales_D', 'low_SA', '0_P'), 2079),
#  (('1_L', 'low_SA', '0_WA'), 2077),
#  (('1_L', 'low_SA', '0_WA', '0_P'), 2066),
#  (('4_NP', 'low_SA', '0_P'), 2066),
#  (('Neutrale_SAT', '3_TSC', '0_P'), 2058),
#  (('Sufficiente_LE', '0_WA', '0_P'), 2036),
#  (('Insufficiente_LE', '3_TSC', '0_WA'), 2016),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_P'), 2010),
#  (('Insufficiente_LE', '3_TSC', '0_WA', '0_P'), 2001),
#  (('technical_D', '0_L', '0_P'), 1998),
#  (('Buono_LE', 'low_SA', '0_P'), 1948),
#  (('Soddisfatto_SAT', 'low_SA', '0_P'), 1947),
#  (('1_WA', '0_L', '0_P'), 1928),
#  (('251-272_AMH', '0_WA', '0_P'), 1879),
#  (('support_D', '0_WA', '0_P'), 1868),
#  (('3_TSC', 'low_SA', '0_L', '0_WA'), 1843),
#  (('2_NP', '3_TSC', '0_P'), 1839),
#  (('4_NP', 'low_SA', '0_L'), 1838),
#  (('Insufficiente_LE', '0_L', '0_WA'), 1837),
#  (('4_NP', 'medium_SA', '0_P'), 1837),
#  (('sales_D', 'low_SA', '0_WA'), 1834),
#  (('Neutrale_SAT', '3_TSC', '0_WA'), 1832),
#  (('3_TSC', 'low_SA', '0_L', '0_WA', '0_P'), 1830),
#  (('3_NP', 'medium_SA', '0_L'), 1824),
#  (('Insufficiente_LE', 'low_SA', '0_P'), 1821),
#  (('4_NP', 'low_SA', '0_L', '0_P'), 1820),
#  (('sales_D', 'low_SA', '0_WA', '0_P'), 1819),
#  (('Soddisfatto_SAT', 'medium_SA', '0_P'), 1819),
#  (('Sufficiente_LE', '0_L', '0_WA'), 1814),
#  (('3_NP', 'medium_SA', '0_P'), 1811),
#  (('Neutrale_SAT', '3_TSC', '0_WA', '0_P'), 1810),
#  (('Discreto_LE', '0_WA', '0_P'), 1808),
#  (('Discreto_LE', '0_L', '0_WA'), 1807),
#  (('3_TSC', 'medium_SA', '0_L', '0_WA'), 1802),
#  (('Insufficiente_LE', '0_L', '0_WA', '0_P'), 1800),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_P'), 1794),
#  (('3_NP', 'medium_SA', '0_L', '0_P'), 1779),
#  (('4_NP', '3_TSC', '0_L'), 1774),
#  (('3_NP', '3_TSC', '0_L'), 1773),
#  (('3_NP', 'low_SA', '0_P'), 1766),
#  (('Sufficiente_LE', '0_L', '0_WA', '0_P'), 1762),
#  (('5_NP', '0_L', '0_WA'), 1762),
#  (('3_NP', 'low_SA', '0_L'), 1754),
#  (('Discreto_LE', '0_L', '0_WA', '0_P'), 1753),
#  (('4_NP', 'medium_SA', '0_L'), 1752),
#  (('Ottimo_LE', '0_L', '0_P'), 1748),
#  (('3_NP', '3_TSC', '0_P'), 1747),
#  (('3_TSC', 'medium_SA', '0_L', '0_WA', '0_P'), 1744),
#  (('Soddisfatto_SAT', '3_TSC', '0_L'), 1741),
#  (('229-250_AMH', '0_WA', '0_P'), 1739),
#  (('4_NP', 'low_SA', '0_WA'), 1739),
#  (('3_NP', '3_TSC', '0_L', '0_P'), 1738),
#  (('Soddisfatto_SAT', 'medium_SA', '0_L'), 1737),
#  (('4_NP', '3_TSC', '0_P'), 1734),
#  (('3_NP', 'low_SA', '0_L', '0_P'), 1729),
#  (('Neutrale_SAT', 'low_SA', '0_P'), 1728),
#  (('2_NP', '3_TSC', '0_WA'), 1727),
#  (('4_NP', 'low_SA', '0_WA', '0_P'), 1726),
#  (('sales_D', '3_TSC', '0_P'), 1722),
#  (('5_NP', '0_L', '0_WA', '0_P'), 1720),
#  (('Soddisfatto_SAT', '3_TSC', '0_P'), 1719),
#  (('2_NP', '3_TSC', '0_WA', '0_P'), 1715),
#  (('4_NP', '3_TSC', '0_L', '0_P'), 1713),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_WA'), 1710),
#  (('Buono_LE', 'low_SA', '0_WA'), 1709),
#  (('Soddisfatto_SAT', 'low_SA', '0_L'), 1708),
#  (('sales_D', 'medium_SA', '0_P'), 1704),
#  (('163-184_AMH', '0_L', '0_P'), 1701),
#  (('Soddisfatto_SAT', '3_TSC', '0_L', '0_P'), 1700),
#  (('Soddisfatto_SAT', 'low_SA', '0_L', '0_P'), 1697),
#  (('Buono_LE', 'low_SA', '0_WA', '0_P'), 1695),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1693),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_L'), 1684),
#  (('Soddisfatto_SAT', 'medium_SA', '0_L', '0_P'), 1683),
#  (('4_NP', 'medium_SA', '0_L', '0_P'), 1680),
#  (('technical_D', '0_L', '0_WA'), 1675),
#  (('141-162_AMH', '0_L', '0_P'), 1670),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_L', '0_P'), 1666),
#  (('Molto soddisfatto_SAT', '3_TSC', '0_L'), 1663),
#  (('support_D', '0_L', '0_P'), 1657),
#  (('technical_D', '0_L', '0_WA', '0_P'), 1655),
#  (('Soddisfatto_SAT', 'low_SA', '0_WA'), 1651),
#  (('Buono_LE', 'medium_SA', '0_P'), 1644),
#  (('Soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1643),
#  (('141-162_AMH', '3_TSC', '0_P'), 1641),
#  (('4_TSC', '0_L', '0_P'), 1635),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_L'), 1632),
#  (('4_NP', 'medium_SA', '0_WA'), 1626),
#  (('185-206_AMH', '0_L', '0_P'), 1620),
#  (('Molto soddisfatto_SAT', '3_TSC', '0_P'), 1618),
#  (('Molto soddisfatto_SAT', '3_TSC', '0_L', '0_P'), 1613),
#  (('Insufficiente_LE', 'low_SA', '0_WA'), 1598),
#  (('Insufficiente_LE', 'low_SA', '0_WA', '0_P'), 1590),
#  (('1_L', '3_TSC', '0_P'), 1571),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_L', '0_P'), 1571),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_WA'), 1569),
#  (('4_NP', 'medium_SA', '0_WA', '0_P'), 1569),
#  (('2_NP', '1_L', '0_P'), 1555),
#  (('251-272_AMH', '0_L', '0_P'), 1548),
#  (('3_NP', 'medium_SA', '0_WA'), 1540),
#  (('Soddisfatto_SAT', 'medium_SA', '0_WA'), 1539),
#  (('229-250_AMH', '0_L', '0_P'), 1536),
#  (('Molto soddisfatto_SAT', '4_NP', '0_P'), 1535),
#  (('2_NP', 'Insufficiente_LE', '0_P'), 1533),
#  (('sales_D', '3_TSC', '0_WA'), 1529),
#  (('2_NP', '1_L', '3_TSC'), 1528),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_WA', '0_P'), 1522),
#  (('2_TSC', 'low_SA', '0_P'), 1519),
#  (('207-228_AMH', '0_L', '0_P'), 1518),
#  (('2_NP', '1_L', '3_TSC', '0_P'), 1516),
#  (('1_L', '3_TSC', '0_WA'), 1512),
#  (('Neutrale_SAT', 'medium_SA', '0_P'), 1512),
#  (('4_NP', '3_TSC', '0_WA'), 1511),
#  (('Neutrale_SAT', 'low_SA', '0_WA'), 1509),
#  (('3_NP', 'medium_SA', '0_L', '0_WA'), 1508),
#  (('2_TSC', 'low_SA', '0_L'), 1505),
#  (('3_NP', 'medium_SA', '0_WA', '0_P'), 1504),
#  (('4_NP', 'low_SA', '0_L', '0_WA'), 1504),
#  (('1_L', '3_TSC', '0_WA', '0_P'), 1500),
#  (('Soddisfatto_SAT', '4_NP', '0_P'), 1500)]

# %%
closed_patterns = apriori(hr_baskets_list, supp=10, zmin=3, target = 'c')

# %%
len(closed_patterns)
# Out:
# 189

# %%
closed_patterns.sort(key=lambda pattern: pattern[1], reverse=True)
closed_patterns
# Out:
# [(('0_L', '0_WA', '0_P'), 9200),
#  (('low_SA', '0_WA', '0_P'), 6228),
#  (('3_TSC', '0_WA', '0_P'), 5446),
#  (('medium_SA', '0_WA', '0_P'), 5371),
#  (('low_SA', '0_L', '0_P'), 5092),
#  (('medium_SA', '0_L', '0_P'), 4953),
#  (('3_TSC', '0_L', '0_P'), 4738),
#  (('medium_SA', '0_L', '0_WA'), 4266),
#  (('low_SA', '0_L', '0_WA'), 4199),
#  (('low_SA', '0_L', '0_WA', '0_P'), 4162),
#  (('medium_SA', '0_L', '0_WA', '0_P'), 4132),
#  (('3_TSC', '0_L', '0_WA'), 4036),
#  (('3_TSC', '0_L', '0_WA', '0_P'), 3946),
#  (('3_NP', '0_L', '0_P'), 3888),
#  (('4_NP', '0_L', '0_P'), 3843),
#  (('Soddisfatto_SAT', '0_L', '0_P'), 3750),
#  (('4_NP', '0_WA', '0_P'), 3590),
#  (('Molto soddisfatto_SAT', '0_L', '0_P'), 3549),
#  (('Molto soddisfatto_SAT', '0_WA', '0_P'), 3483),
#  (('sales_D', '0_WA', '0_P'), 3482),
#  (('Soddisfatto_SAT', '0_WA', '0_P'), 3459),
#  (('Buono_LE', '0_WA', '0_P'), 3389),
#  (('1_L', '0_WA', '0_P'), 3387),
#  (('4_NP', '0_L', '0_WA'), 3300),
#  (('3_NP', '0_L', '0_WA'), 3274),
#  (('3_NP', '0_WA', '0_P'), 3271),
#  (('4_NP', '0_L', '0_WA', '0_P'), 3211),
#  (('3_NP', '0_L', '0_WA', '0_P'), 3200),
#  (('3_TSC', 'low_SA', '0_P'), 3173),
#  (('Soddisfatto_SAT', '0_L', '0_WA'), 3142),
#  (('2_TSC', '0_L', '0_P'), 3137),
#  (('Insufficiente_LE', '0_WA', '0_P'), 3080),
#  (('Soddisfatto_SAT', '0_L', '0_WA', '0_P'), 3077),
#  (('Neutrale_SAT', '0_WA', '0_P'), 3066),
#  (('sales_D', '0_L', '0_P'), 3033),
#  (('Molto soddisfatto_SAT', '0_L', '0_WA'), 3021),
#  (('Molto soddisfatto_SAT', '0_L', '0_WA', '0_P'), 2940),
#  (('Buono_LE', '0_L', '0_P'), 2930),
#  (('3_TSC', 'low_SA', '0_WA'), 2784),
#  (('3_TSC', 'low_SA', '0_WA', '0_P'), 2763),
#  (('2_TSC', '0_WA', '0_P'), 2642),
#  (('3_TSC', 'medium_SA', '0_P'), 2639),
#  (('2_TSC', '0_L', '0_WA'), 2634),
#  (('2_TSC', '0_L', '0_WA', '0_P'), 2590),
#  (('sales_D', '0_L', '0_WA'), 2585),
#  (('sales_D', '0_L', '0_WA', '0_P'), 2517),
#  (('Neutrale_SAT', '0_L', '0_P'), 2512),
#  (('Buono_LE', '0_L', '0_WA'), 2494),
#  (('Buono_LE', '0_L', '0_WA', '0_P'), 2447),
#  (('3_TSC', 'medium_SA', '0_WA'), 2327),
#  (('technical_D', '0_WA', '0_P'), 2316),
#  (('5_NP', '0_WA', '0_P'), 2303),
#  (('Ottimo_LE', '0_WA', '0_P'), 2274),
#  (('3_TSC', 'medium_SA', '0_WA', '0_P'), 2265),
#  (('141-162_AMH', '0_WA', '0_P'), 2245),
#  (('3_TSC', 'low_SA', '0_L'), 2219),
#  (('4_TSC', '0_WA', '0_P'), 2213),
#  (('Insufficiente_LE', '0_L', '0_P'), 2202),
#  (('Insufficiente_LE', '3_TSC', '0_P'), 2201),
#  (('3_TSC', 'low_SA', '0_L', '0_P'), 2198),
#  (('3_TSC', 'medium_SA', '0_L'), 2164),
#  (('1_L', 'low_SA', '0_P'), 2158),
#  (('Neutrale_SAT', '0_L', '0_WA'), 2155),
#  (('2_NP', '0_WA', '0_P'), 2144),
#  (('Sufficiente_LE', '0_L', '0_P'), 2138),
#  (('Discreto_LE', '0_L', '0_P'), 2110),
#  (('Neutrale_SAT', '0_L', '0_WA', '0_P'), 2101),
#  (('5_NP', '0_L', '0_P'), 2099),
#  (('3_TSC', 'medium_SA', '0_L', '0_P'), 2089),
#  (('sales_D', 'low_SA', '0_P'), 2079),
#  (('1_L', 'low_SA', '0_WA'), 2077),
#  (('1_L', 'low_SA', '0_WA', '0_P'), 2066),
#  (('4_NP', 'low_SA', '0_P'), 2066),
#  (('Neutrale_SAT', '3_TSC', '0_P'), 2058),
#  (('Sufficiente_LE', '0_WA', '0_P'), 2036),
#  (('Insufficiente_LE', '3_TSC', '0_WA'), 2016),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_P'), 2010),
#  (('Insufficiente_LE', '3_TSC', '0_WA', '0_P'), 2001),
#  (('technical_D', '0_L', '0_P'), 1998),
#  (('Buono_LE', 'low_SA', '0_P'), 1948),
#  (('Soddisfatto_SAT', 'low_SA', '0_P'), 1947),
#  (('1_WA', '0_L', '0_P'), 1928),
#  (('251-272_AMH', '0_WA', '0_P'), 1879),
#  (('support_D', '0_WA', '0_P'), 1868),
#  (('3_TSC', 'low_SA', '0_L', '0_WA'), 1843),
#  (('2_NP', '3_TSC', '0_P'), 1839),
#  (('4_NP', 'low_SA', '0_L'), 1838),
#  (('Insufficiente_LE', '0_L', '0_WA'), 1837),
#  (('4_NP', 'medium_SA', '0_P'), 1837),
#  (('sales_D', 'low_SA', '0_WA'), 1834),
#  (('Neutrale_SAT', '3_TSC', '0_WA'), 1832),
#  (('3_TSC', 'low_SA', '0_L', '0_WA', '0_P'), 1830),
#  (('3_NP', 'medium_SA', '0_L'), 1824),
#  (('Insufficiente_LE', 'low_SA', '0_P'), 1821),
#  (('4_NP', 'low_SA', '0_L', '0_P'), 1820),
#  (('sales_D', 'low_SA', '0_WA', '0_P'), 1819),
#  (('Soddisfatto_SAT', 'medium_SA', '0_P'), 1819),
#  (('Sufficiente_LE', '0_L', '0_WA'), 1814),
#  (('3_NP', 'medium_SA', '0_P'), 1811),
#  (('Neutrale_SAT', '3_TSC', '0_WA', '0_P'), 1810),
#  (('Discreto_LE', '0_WA', '0_P'), 1808),
#  (('Discreto_LE', '0_L', '0_WA'), 1807),
#  (('3_TSC', 'medium_SA', '0_L', '0_WA'), 1802),
#  (('Insufficiente_LE', '0_L', '0_WA', '0_P'), 1800),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_P'), 1794),
#  (('3_NP', 'medium_SA', '0_L', '0_P'), 1779),
#  (('4_NP', '3_TSC', '0_L'), 1774),
#  (('3_NP', '3_TSC', '0_L'), 1773),
#  (('3_NP', 'low_SA', '0_P'), 1766),
#  (('Sufficiente_LE', '0_L', '0_WA', '0_P'), 1762),
#  (('5_NP', '0_L', '0_WA'), 1762),
#  (('3_NP', 'low_SA', '0_L'), 1754),
#  (('Discreto_LE', '0_L', '0_WA', '0_P'), 1753),
#  (('4_NP', 'medium_SA', '0_L'), 1752),
#  (('Ottimo_LE', '0_L', '0_P'), 1748),
#  (('3_NP', '3_TSC', '0_P'), 1747),
#  (('3_TSC', 'medium_SA', '0_L', '0_WA', '0_P'), 1744),
#  (('Soddisfatto_SAT', '3_TSC', '0_L'), 1741),
#  (('229-250_AMH', '0_WA', '0_P'), 1739),
#  (('4_NP', 'low_SA', '0_WA'), 1739),
#  (('3_NP', '3_TSC', '0_L', '0_P'), 1738),
#  (('Soddisfatto_SAT', 'medium_SA', '0_L'), 1737),
#  (('4_NP', '3_TSC', '0_P'), 1734),
#  (('3_NP', 'low_SA', '0_L', '0_P'), 1729),
#  (('Neutrale_SAT', 'low_SA', '0_P'), 1728),
#  (('2_NP', '3_TSC', '0_WA'), 1727),
#  (('4_NP', 'low_SA', '0_WA', '0_P'), 1726),
#  (('sales_D', '3_TSC', '0_P'), 1722),
#  (('5_NP', '0_L', '0_WA', '0_P'), 1720),
#  (('Soddisfatto_SAT', '3_TSC', '0_P'), 1719),
#  (('2_NP', '3_TSC', '0_WA', '0_P'), 1715),
#  (('4_NP', '3_TSC', '0_L', '0_P'), 1713),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_WA'), 1710),
#  (('Buono_LE', 'low_SA', '0_WA'), 1709),
#  (('Soddisfatto_SAT', 'low_SA', '0_L'), 1708),
#  (('sales_D', 'medium_SA', '0_P'), 1704),
#  (('163-184_AMH', '0_L', '0_P'), 1701),
#  (('Soddisfatto_SAT', '3_TSC', '0_L', '0_P'), 1700),
#  (('Soddisfatto_SAT', 'low_SA', '0_L', '0_P'), 1697),
#  (('Buono_LE', 'low_SA', '0_WA', '0_P'), 1695),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1693),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_L'), 1684),
#  (('Soddisfatto_SAT', 'medium_SA', '0_L', '0_P'), 1683),
#  (('4_NP', 'medium_SA', '0_L', '0_P'), 1680),
#  (('technical_D', '0_L', '0_WA'), 1675),
#  (('141-162_AMH', '0_L', '0_P'), 1670),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_L', '0_P'), 1666),
#  (('Molto soddisfatto_SAT', '3_TSC', '0_L'), 1663),
#  (('support_D', '0_L', '0_P'), 1657),
#  (('technical_D', '0_L', '0_WA', '0_P'), 1655),
#  (('Soddisfatto_SAT', 'low_SA', '0_WA'), 1651),
#  (('Buono_LE', 'medium_SA', '0_P'), 1644),
#  (('Soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1643),
#  (('141-162_AMH', '3_TSC', '0_P'), 1641),
#  (('4_TSC', '0_L', '0_P'), 1635),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_L'), 1632),
#  (('4_NP', 'medium_SA', '0_WA'), 1626),
#  (('185-206_AMH', '0_L', '0_P'), 1620),
#  (('Molto soddisfatto_SAT', '3_TSC', '0_P'), 1618),
#  (('Molto soddisfatto_SAT', '3_TSC', '0_L', '0_P'), 1613),
#  (('Insufficiente_LE', 'low_SA', '0_WA'), 1598),
#  (('Insufficiente_LE', 'low_SA', '0_WA', '0_P'), 1590),
#  (('1_L', '3_TSC', '0_P'), 1571),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_L', '0_P'), 1571),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_WA'), 1569),
#  (('4_NP', 'medium_SA', '0_WA', '0_P'), 1569),
#  (('2_NP', '1_L', '0_P'), 1555),
#  (('251-272_AMH', '0_L', '0_P'), 1548),
#  (('3_NP', 'medium_SA', '0_WA'), 1540),
#  (('Soddisfatto_SAT', 'medium_SA', '0_WA'), 1539),
#  (('229-250_AMH', '0_L', '0_P'), 1536),
#  (('Molto soddisfatto_SAT', '4_NP', '0_P'), 1535),
#  (('2_NP', 'Insufficiente_LE', '0_P'), 1533),
#  (('sales_D', '3_TSC', '0_WA'), 1529),
#  (('2_NP', '1_L', '3_TSC'), 1528),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_WA', '0_P'), 1522),
#  (('2_TSC', 'low_SA', '0_P'), 1519),
#  (('207-228_AMH', '0_L', '0_P'), 1518),
#  (('2_NP', '1_L', '3_TSC', '0_P'), 1516),
#  (('1_L', '3_TSC', '0_WA'), 1512),
#  (('Neutrale_SAT', 'medium_SA', '0_P'), 1512),
#  (('4_NP', '3_TSC', '0_WA'), 1511),
#  (('Neutrale_SAT', 'low_SA', '0_WA'), 1509),
#  (('3_NP', 'medium_SA', '0_L', '0_WA'), 1508),
#  (('2_TSC', 'low_SA', '0_L'), 1505),
#  (('3_NP', 'medium_SA', '0_WA', '0_P'), 1504),
#  (('4_NP', 'low_SA', '0_L', '0_WA'), 1504),
#  (('1_L', '3_TSC', '0_WA', '0_P'), 1500),
#  (('Soddisfatto_SAT', '4_NP', '0_P'), 1500)]

# %%
maximal_patterns = apriori(hr_baskets_list, supp=10, zmin=3, target = 'm')

# %%
len(maximal_patterns)
# Out:
# 75

# %%
max_pat = maximal_patterns[0]
max_pat
# Out:
# (('185-206_AMH', '0_L', '0_P'), 1620)

# %%
max_pat[1]
# Out:
# 1620

# %%
maximal_patterns
# Out:
# [(('185-206_AMH', '0_L', '0_P'), 1620),
#  (('207-228_AMH', '0_L', '0_P'), 1518),
#  (('163-184_AMH', '0_L', '0_P'), 1701),
#  (('229-250_AMH', '0_L', '0_P'), 1536),
#  (('229-250_AMH', '0_WA', '0_P'), 1739),
#  (('1_WA', '0_L', '0_P'), 1928),
#  (('Discreto_LE', '0_L', '0_WA', '0_P'), 1753),
#  (('support_D', '0_L', '0_P'), 1657),
#  (('support_D', '0_WA', '0_P'), 1868),
#  (('251-272_AMH', '0_L', '0_P'), 1548),
#  (('251-272_AMH', '0_WA', '0_P'), 1879),
#  (('2_NP', '1_L', '3_TSC', '0_P'), 1516),
#  (('2_NP', 'Insufficiente_LE', '0_P'), 1533),
#  (('2_NP', '3_TSC', '0_WA', '0_P'), 1715),
#  (('Sufficiente_LE', '0_L', '0_WA', '0_P'), 1762),
#  (('4_TSC', '0_L', '0_P'), 1635),
#  (('4_TSC', '0_WA', '0_P'), 2213),
#  (('141-162_AMH', '3_TSC', '0_P'), 1641),
#  (('141-162_AMH', '0_L', '0_P'), 1670),
#  (('141-162_AMH', '0_WA', '0_P'), 2245),
#  (('Ottimo_LE', '0_L', '0_P'), 1748),
#  (('Ottimo_LE', '0_WA', '0_P'), 2274),
#  (('technical_D', '0_L', '0_WA', '0_P'), 1655),
#  (('5_NP', '0_L', '0_WA', '0_P'), 1720),
#  (('2_TSC', 'low_SA', '0_L'), 1505),
#  (('2_TSC', 'low_SA', '0_P'), 1519),
#  (('2_TSC', '0_L', '0_WA', '0_P'), 2590),
#  (('1_L', '3_TSC', '0_WA', '0_P'), 1500),
#  (('1_L', 'low_SA', '0_WA', '0_P'), 2066),
#  (('Insufficiente_LE', '3_TSC', '0_WA', '0_P'), 2001),
#  (('Insufficiente_LE', 'low_SA', '0_WA', '0_P'), 1590),
#  (('Insufficiente_LE', '0_L', '0_WA', '0_P'), 1800),
#  (('Neutrale_SAT', '3_TSC', '0_WA', '0_P'), 1810),
#  (('Neutrale_SAT', 'medium_SA', '0_P'), 1512),
#  (('Neutrale_SAT', 'low_SA', '0_WA'), 1509),
#  (('Neutrale_SAT', 'low_SA', '0_P'), 1728),
#  (('Neutrale_SAT', '0_L', '0_WA', '0_P'), 2101),
#  (('Buono_LE', 'medium_SA', '0_P'), 1644),
#  (('Buono_LE', 'low_SA', '0_WA', '0_P'), 1695),
#  (('Buono_LE', '0_L', '0_WA', '0_P'), 2447),
#  (('3_NP', '3_TSC', '0_L', '0_P'), 1738),
#  (('3_NP', 'medium_SA', '0_L', '0_WA'), 1508),
#  (('3_NP', 'medium_SA', '0_L', '0_P'), 1779),
#  (('3_NP', 'medium_SA', '0_WA', '0_P'), 1504),
#  (('3_NP', 'low_SA', '0_L', '0_P'), 1729),
#  (('3_NP', '0_L', '0_WA', '0_P'), 3200),
#  (('sales_D', '3_TSC', '0_WA'), 1529),
#  (('sales_D', '3_TSC', '0_P'), 1722),
#  (('sales_D', 'medium_SA', '0_P'), 1704),
#  (('sales_D', 'low_SA', '0_WA', '0_P'), 1819),
#  (('sales_D', '0_L', '0_WA', '0_P'), 2517),
#  (('Molto soddisfatto_SAT', '4_NP', '0_P'), 1535),
#  (('Molto soddisfatto_SAT', '3_TSC', '0_L', '0_P'), 1613),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_L', '0_P'), 1571),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_WA', '0_P'), 1522),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_L', '0_P'), 1666),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1693),
#  (('Molto soddisfatto_SAT', '0_L', '0_WA', '0_P'), 2940),
#  (('Soddisfatto_SAT', '4_NP', '0_P'), 1500),
#  (('Soddisfatto_SAT', '3_TSC', '0_L', '0_P'), 1700),
#  (('Soddisfatto_SAT', 'medium_SA', '0_L', '0_P'), 1683),
#  (('Soddisfatto_SAT', 'medium_SA', '0_WA'), 1539),
#  (('Soddisfatto_SAT', 'low_SA', '0_L', '0_P'), 1697),
#  (('Soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1643),
#  (('Soddisfatto_SAT', '0_L', '0_WA', '0_P'), 3077),
#  (('4_NP', '3_TSC', '0_L', '0_P'), 1713),
#  (('4_NP', '3_TSC', '0_WA'), 1511),
#  (('4_NP', 'medium_SA', '0_L', '0_P'), 1680),
#  (('4_NP', 'medium_SA', '0_WA', '0_P'), 1569),
#  (('4_NP', 'low_SA', '0_L', '0_WA'), 1504),
#  (('4_NP', 'low_SA', '0_L', '0_P'), 1820),
#  (('4_NP', 'low_SA', '0_WA', '0_P'), 1726),
#  (('4_NP', '0_L', '0_WA', '0_P'), 3211),
#  (('3_TSC', 'medium_SA', '0_L', '0_WA', '0_P'), 1744),
#  (('3_TSC', 'low_SA', '0_L', '0_WA', '0_P'), 1830)]

# %%
maximal_patterns.sort(key=lambda pattern: pattern[1], reverse=True)
maximal_patterns
# Out:
# [(('4_NP', '0_L', '0_WA', '0_P'), 3211),
#  (('3_NP', '0_L', '0_WA', '0_P'), 3200),
#  (('Soddisfatto_SAT', '0_L', '0_WA', '0_P'), 3077),
#  (('Molto soddisfatto_SAT', '0_L', '0_WA', '0_P'), 2940),
#  (('2_TSC', '0_L', '0_WA', '0_P'), 2590),
#  (('sales_D', '0_L', '0_WA', '0_P'), 2517),
#  (('Buono_LE', '0_L', '0_WA', '0_P'), 2447),
#  (('Ottimo_LE', '0_WA', '0_P'), 2274),
#  (('141-162_AMH', '0_WA', '0_P'), 2245),
#  (('4_TSC', '0_WA', '0_P'), 2213),
#  (('Neutrale_SAT', '0_L', '0_WA', '0_P'), 2101),
#  (('1_L', 'low_SA', '0_WA', '0_P'), 2066),
#  (('Insufficiente_LE', '3_TSC', '0_WA', '0_P'), 2001),
#  (('1_WA', '0_L', '0_P'), 1928),
#  (('251-272_AMH', '0_WA', '0_P'), 1879),
#  (('support_D', '0_WA', '0_P'), 1868),
#  (('3_TSC', 'low_SA', '0_L', '0_WA', '0_P'), 1830),
#  (('4_NP', 'low_SA', '0_L', '0_P'), 1820),
#  (('sales_D', 'low_SA', '0_WA', '0_P'), 1819),
#  (('Neutrale_SAT', '3_TSC', '0_WA', '0_P'), 1810),
#  (('Insufficiente_LE', '0_L', '0_WA', '0_P'), 1800),
#  (('3_NP', 'medium_SA', '0_L', '0_P'), 1779),
#  (('Sufficiente_LE', '0_L', '0_WA', '0_P'), 1762),
#  (('Discreto_LE', '0_L', '0_WA', '0_P'), 1753),
#  (('Ottimo_LE', '0_L', '0_P'), 1748),
#  (('3_TSC', 'medium_SA', '0_L', '0_WA', '0_P'), 1744),
#  (('229-250_AMH', '0_WA', '0_P'), 1739),
#  (('3_NP', '3_TSC', '0_L', '0_P'), 1738),
#  (('3_NP', 'low_SA', '0_L', '0_P'), 1729),
#  (('Neutrale_SAT', 'low_SA', '0_P'), 1728),
#  (('4_NP', 'low_SA', '0_WA', '0_P'), 1726),
#  (('sales_D', '3_TSC', '0_P'), 1722),
#  (('5_NP', '0_L', '0_WA', '0_P'), 1720),
#  (('2_NP', '3_TSC', '0_WA', '0_P'), 1715),
#  (('4_NP', '3_TSC', '0_L', '0_P'), 1713),
#  (('sales_D', 'medium_SA', '0_P'), 1704),
#  (('163-184_AMH', '0_L', '0_P'), 1701),
#  (('Soddisfatto_SAT', '3_TSC', '0_L', '0_P'), 1700),
#  (('Soddisfatto_SAT', 'low_SA', '0_L', '0_P'), 1697),
#  (('Buono_LE', 'low_SA', '0_WA', '0_P'), 1695),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1693),
#  (('Soddisfatto_SAT', 'medium_SA', '0_L', '0_P'), 1683),
#  (('4_NP', 'medium_SA', '0_L', '0_P'), 1680),
#  (('141-162_AMH', '0_L', '0_P'), 1670),
#  (('Molto soddisfatto_SAT', 'low_SA', '0_L', '0_P'), 1666),
#  (('support_D', '0_L', '0_P'), 1657),
#  (('technical_D', '0_L', '0_WA', '0_P'), 1655),
#  (('Buono_LE', 'medium_SA', '0_P'), 1644),
#  (('Soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1643),
#  (('141-162_AMH', '3_TSC', '0_P'), 1641),
#  (('4_TSC', '0_L', '0_P'), 1635),
#  (('185-206_AMH', '0_L', '0_P'), 1620),
#  (('Molto soddisfatto_SAT', '3_TSC', '0_L', '0_P'), 1613),
#  (('Insufficiente_LE', 'low_SA', '0_WA', '0_P'), 1590),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_L', '0_P'), 1571),
#  (('4_NP', 'medium_SA', '0_WA', '0_P'), 1569),
#  (('251-272_AMH', '0_L', '0_P'), 1548),
#  (('Soddisfatto_SAT', 'medium_SA', '0_WA'), 1539),
#  (('229-250_AMH', '0_L', '0_P'), 1536),
#  (('Molto soddisfatto_SAT', '4_NP', '0_P'), 1535),
#  (('2_NP', 'Insufficiente_LE', '0_P'), 1533),
#  (('sales_D', '3_TSC', '0_WA'), 1529),
#  (('Molto soddisfatto_SAT', 'medium_SA', '0_WA', '0_P'), 1522),
#  (('2_TSC', 'low_SA', '0_P'), 1519),
#  (('207-228_AMH', '0_L', '0_P'), 1518),
#  (('2_NP', '1_L', '3_TSC', '0_P'), 1516),
#  (('Neutrale_SAT', 'medium_SA', '0_P'), 1512),
#  (('4_NP', '3_TSC', '0_WA'), 1511),
#  (('Neutrale_SAT', 'low_SA', '0_WA'), 1509),
#  (('3_NP', 'medium_SA', '0_L', '0_WA'), 1508),
#  (('2_TSC', 'low_SA', '0_L'), 1505),
#  (('3_NP', 'medium_SA', '0_WA', '0_P'), 1504),
#  (('4_NP', 'low_SA', '0_L', '0_WA'), 1504),
#  (('1_L', '3_TSC', '0_WA', '0_P'), 1500),
#  (('Soddisfatto_SAT', '4_NP', '0_P'), 1500)]

# %% [markdown]
# # Regole

# %%
rules = apriori(hr_baskets_list, supp=10, zmin=2, target='r', conf=80, report='ascl')

# %%
first_rule = rules[0]
first_rule
# Out:
# ('0_WA',
#  ('Insoddisfatto_SAT',),
#  1337,
#  0.08913927595173012,
#  0.8877822045152722,
#  1.0378679100175034)

# %%
len(rules)
# Out:
# 484

# %%
rules.sort(key=lambda rule: rule[5], reverse=True)
rules
# Out:
# [('2_NP',
#   ('1_L', '3_TSC', '0_P'),
#   1516,
#   0.10107340489365958,
#   0.9649904519414386,
#   6.061093713848257),
#  ('2_NP',
#   ('1_L', '3_TSC', '0_WA', '0_P'),
#   1446,
#   0.09640642709513968,
#   0.964,
#   6.05487269681742),
#  ('2_NP',
#   ('1_L', '3_TSC'),
#   1528,
#   0.1018734582305487,
#   0.9634300126103404,
#   6.051292612706238),
#  ('2_NP',
#   ('1_L', '3_TSC', '0_WA'),
#   1455,
#   0.09700646709780653,
#   0.9623015873015873,
#   6.044204986573077),
#  ('1_L',
#   ('2_NP', '3_TSC', '0_WA', '0_P'),
#   1446,
#   0.09640642709513968,
#   0.8431486880466472,
#   3.5414133777685977),
#  ('1_L',
#   ('2_NP', 'Insufficiente_LE', '0_P'),
#   1292,
#   0.0861390759383959,
#   0.8427919112850619,
#   3.5399148354423535),
#  ('1_L',
#   ('2_NP', '3_TSC', '0_WA'),
#   1455,
#   0.09700646709780653,
#   0.842501447596989,
#   3.5386948228807724),
#  ('Insufficiente_LE',
#   ('2_NP', '1_L', '3_TSC', '0_P'),
#   1281,
#   0.08540569371291419,
#   0.8449868073878628,
#   3.513711428891199),
#  ('Insufficiente_LE',
#   ('2_NP', '1_L', '3_TSC'),
#   1290,
#   0.08600573371558104,
#   0.8442408376963351,
#   3.5106094606618603),
#  ('1_L',
#   ('2_NP', 'Insufficiente_LE'),
#   1301,
#   0.08673911594106273,
#   0.8350449293966624,
#   3.5073757759788684),
#  ('1_L',
#   ('2_NP', '3_TSC', '0_P'),
#   1516,
#   0.10107340489365958,
#   0.8243610657966286,
#   3.4625011553860636),
#  ('1_L',
#   ('2_NP', '3_TSC'),
#   1528,
#   0.1018734582305487,
#   0.8241639697950378,
#   3.461673308024579),
#  ('Insufficiente_LE',
#   ('2_NP', '1_L', '0_P'),
#   1292,
#   0.0861390759383959,
#   0.8308681672025724,
#   3.455001840829327),
#  ('Insufficiente_LE',
#   ('2_NP', '1_L'),
#   1301,
#   0.08673911594106273,
#   0.8302488832163369,
#   3.4524266701862594),
#  ('Insufficiente_LE',
#   ('1_L', '3_TSC', '0_P'),
#   1291,
#   0.08607240482698847,
#   0.821769573520051,
#   3.4171671287017586),
#  ('Insufficiente_LE',
#   ('1_L', '3_TSC', '0_WA', '0_P'),
#   1232,
#   0.08213880925395026,
#   0.8213333333333334,
#   3.4153531096941134),
#  ('Insufficiente_LE',
#   ('1_L', '3_TSC'),
#   1300,
#   0.0866724448296553,
#   0.819672131147541,
#   3.4084453271643933),
#  ('Insufficiente_LE',
#   ('1_L', '3_TSC', '0_WA'),
#   1238,
#   0.08253883592239483,
#   0.8187830687830688,
#   3.404748336201067),
#  ('3_TSC',
#   ('2_NP', '1_L'),
#   1528,
#   0.1018734582305487,
#   0.9751116783663051,
#   2.2700139785528806),
#  ('3_TSC',
#   ('2_NP', '1_L', '0_P'),
#   1516,
#   0.10107340489365958,
#   0.97491961414791,
#   2.2695668621146208),
#  ('3_TSC',
#   ('2_NP', 'Insufficiente_LE', '0_P'),
#   1375,
#   0.09167277818521234,
#   0.8969341161121983,
#   2.088020302276403),
#  ('3_TSC',
#   ('2_NP', 'Insufficiente_LE'),
#   1387,
#   0.09247283152210148,
#   0.8902439024390244,
#   2.072445800509534),
#  ('0_L',
#   ('Molto soddisfatto_SAT', '3_TSC'),
#   1663,
#   0.11087405827055137,
#   0.9970023980815348,
#   1.3085438369640305),
#  ('0_L',
#   ('Molto soddisfatto_SAT', '3_TSC', '0_P'),
#   1613,
#   0.10754050270018001,
#   0.9969097651421508,
#   1.3084222582575358),
#  ('0_L',
#   ('3_NP', '3_TSC'),
#   1773,
#   0.11820788052536836,
#   0.9949494949494949,
#   1.3058494465127297),
#  ('0_L',
#   ('3_NP', '3_TSC', '0_P'),
#   1738,
#   0.11587439162610841,
#   0.994848311390956,
#   1.3057166453056481),
#  ('0_L',
#   ('Soddisfatto_SAT', '3_TSC', '0_P'),
#   1700,
#   0.11334088939262618,
#   0.9889470622454916,
#   1.2979713848985062),
#  ('0_L',
#   ('4_NP', '3_TSC', '0_P'),
#   1713,
#   0.11420761384092273,
#   0.9878892733564014,
#   1.2965830601218642),
#  ('0_L',
#   ('Soddisfatto_SAT', '3_TSC'),
#   1741,
#   0.11607440496033068,
#   0.9875212705615428,
#   1.296100064504076),
#  ('0_L',
#   ('4_NP', '3_TSC'),
#   1774,
#   0.11827455163677579,
#   0.9866518353726362,
#   1.294958949838482),
#  ('0_L',
#   ('2_TSC', 'low_SA'),
#   1505,
#   0.10034002266817788,
#   0.9855926653569089,
#   1.2935688123633424),
#  ('0_L',
#   ('2_TSC', 'low_SA', '0_P'),
#   1497,
#   0.09980665377691846,
#   0.9855167873601053,
#   1.293469224152452),
#  ('0_L',
#   ('4_NP', '3_TSC', '0_WA'),
#   1487,
#   0.09913994266284419,
#   0.9841164791528789,
#   1.2916313502637409),
#  ('0_L',
#   ('2_TSC',),
#   3191,
#   0.21274751650110008,
#   0.9836621454993835,
#   1.2910350472825738),
#  ('0_L',
#   ('2_TSC', '0_P'),
#   3137,
#   0.209147276485099,
#   0.983385579937304,
#   1.2906720610325186),
#  ('0_L',
#   ('3_NP', 'medium_SA'),
#   1824,
#   0.12160810720714714,
#   0.9827586206896551,
#   1.2898491907353988),
#  ('0_L',
#   ('3_NP', 'medium_SA', '0_P'),
#   1779,
#   0.11860790719381292,
#   0.9823302043070127,
#   1.2892869036052577),
#  ('0_L',
#   ('3_NP',),
#   3983,
#   0.2655510367357824,
#   0.9822441430332922,
#   1.2891739500661838),
#  ('0_L',
#   ('3_NP', '0_P'),
#   3888,
#   0.2592172811520768,
#   0.9818181818181818,
#   1.288614885289719),
#  ('0_L',
#   ('185-206_AMH',),
#   1653,
#   0.11020734715647709,
#   0.9810089020771513,
#   1.287552723333496),
#  ('0_L',
#   ('2_TSC', '0_WA'),
#   2634,
#   0.17561170744716315,
#   0.9806403574087863,
#   1.2870690165185847),
#  ('0_L',
#   ('185-206_AMH', '0_P'),
#   1620,
#   0.108007200480032,
#   0.9806295399515739,
#   1.287054818842637),
#  ('0_L',
#   ('2_TSC', '0_WA', '0_P'),
#   2590,
#   0.17267817854523634,
#   0.9803179409538229,
#   1.2866458519746578),
#  ('0_L',
#   ('3_NP', 'low_SA'),
#   1754,
#   0.11694112940862725,
#   0.9793411501954216,
#   1.2853638354726222),
#  ('0_L',
#   ('3_NP', 'medium_SA', '0_WA'),
#   1508,
#   0.10054003600240016,
#   0.9792207792207792,
#   1.285205851201651),
#  ('0_L',
#   ('3_NP', 'low_SA', '0_P'),
#   1729,
#   0.11527435162344156,
#   0.9790486976217441,
#   1.2849799978673906),
#  ('0_L',
#   ('3_NP', '0_WA'),
#   3274,
#   0.21828121874791653,
#   0.9787742899850523,
#   1.2846198438471998),
#  ('0_L',
#   ('3_NP', 'medium_SA', '0_WA', '0_P'),
#   1472,
#   0.09813987599173278,
#   0.9787234042553191,
#   1.284553057440106),
#  ('0_L',
#   ('3_NP', '0_WA', '0_P'),
#   3200,
#   0.2133475565037669,
#   0.9782940996637114,
#   1.2839896045551284),
#  ('0_L',
#   ('163-184_AMH',),
#   1737,
#   0.11580772051470098,
#   0.9769403824521935,
#   1.2822128803290558),
#  ('0_L',
#   ('163-184_AMH', '0_P'),
#   1701,
#   0.1134075605040336,
#   0.9764638346727899,
#   1.2815874217935925),
#  ('0_L',
#   ('Discreto_LE',),
#   2165,
#   0.14434295619707982,
#   0.9739091318038686,
#   1.278234430165053),
#  ('0_L',
#   ('Discreto_LE', '0_P'),
#   2110,
#   0.14067604506967132,
#   0.9732472324723247,
#   1.2773657017721736),
#  ('0_L',
#   ('163-184_AMH', '0_WA'),
#   1462,
#   0.09747316487765852,
#   0.9727212242182302,
#   1.2766753274456804),
#  ('0_L',
#   ('Discreto_LE', '0_WA'),
#   1807,
#   0.12047469831322088,
#   0.9704618689581096,
#   1.2737099730926396),
#  ('0_L',
#   ('Discreto_LE', '0_WA', '0_P'),
#   1753,
#   0.11687445829721982,
#   0.9695796460176991,
#   1.2725520747829426),
#  ('0_L',
#   ('Soddisfatto_SAT', 'medium_SA'),
#   1737,
#   0.11580772051470098,
#   0.9273892151628403,
#   1.2171780572477635),
#  ('0_L',
#   ('Soddisfatto_SAT', 'medium_SA', '0_P'),
#   1683,
#   0.11220748049869991,
#   0.9252336448598131,
#   1.2143489183804985),
#  ('0_L',
#   ('1_WA',),
#   2000,
#   0.13334222281485433,
#   0.9220839096357769,
#   1.2102149598028542),
#  ('0_L',
#   ('1_WA', '0_P'),
#   1928,
#   0.12854190279351957,
#   0.9211657907310081,
#   1.2090099488252004),
#  ('0_L',
#   ('Soddisfatto_SAT', 'medium_SA', '0_WA'),
#   1415,
#   0.09433962264150944,
#   0.9194282001299545,
#   1.2067293991730126),
#  ('0_L',
#   ('4_NP', 'medium_SA'),
#   1752,
#   0.11680778718581239,
#   0.9172774869109948,
#   1.203906635122332),
#  ('0_L',
#   ('Soddisfatto_SAT', '4_NP'),
#   1414,
#   0.09427295153010201,
#   0.9158031088082902,
#   1.201971546116166),
#  ('0_L',
#   ('Soddisfatto_SAT', '4_NP', '0_P'),
#   1373,
#   0.0915394359623975,
#   0.9153333333333333,
#   1.2013549760821374),
#  ('0_L',
#   ('4_NP', 'medium_SA', '0_P'),
#   1680,
#   0.11200746716447763,
#   0.914534567229178,
#   1.2003066130443159),
#  ('0_L',
#   ('4_NP', 'medium_SA', '0_WA'),
#   1481,
#   0.09873991599439963,
#   0.9108241082410824,
#   1.1954367167927893),
#  ('0_L',
#   ('4_NP', 'medium_SA', '0_WA', '0_P'),
#   1424,
#   0.09493966264417628,
#   0.9075844486934354,
#   1.1911847345075985),
#  ('0_L',
#   ('4_NP',),
#   3956,
#   0.26375091672778184,
#   0.9063001145475372,
#   1.1894990740373215),
#  ('0_L',
#   ('Soddisfatto_SAT',),
#   3841,
#   0.2560837389159277,
#   0.9061099315876386,
#   1.189249463062915),
#  ('0_L',
#   ('Soddisfatto_SAT', '0_P'),
#   3750,
#   0.25001666777785186,
#   0.9047044632086851,
#   1.1874048165616966),
#  ('0_L',
#   ('4_NP', '0_P'),
#   3843,
#   0.2562170811387426,
#   0.9046610169491526,
#   1.1873477942964945),
#  ('0_L',
#   ('4_NP', '0_WA'),
#   3300,
#   0.22001466764450964,
#   0.8962520369364476,
#   1.1763111919854548),
#  ('0_L',
#   ('4_NP', '0_WA', '0_P'),
#   3211,
#   0.2140809387292486,
#   0.8944289693593315,
#   1.1739184556720872),
#  ('0_L',
#   ('207-228_AMH',),
#   1569,
#   0.10460697379825322,
#   0.8929994308480365,
#   1.172042217648731),
#  ('0_L',
#   ('Soddisfatto_SAT', '0_WA'),
#   3142,
#   0.20948063204213616,
#   0.8908420754182025,
#   1.1692107358415837),
#  ('0_L',
#   ('207-228_AMH', '0_P'),
#   1518,
#   0.10120674711647443,
#   0.8898007033997656,
#   1.1678439578485371),
#  ('0_L',
#   ('Soddisfatto_SAT', '0_WA', '0_P'),
#   3077,
#   0.20514700980065337,
#   0.8895634576467187,
#   1.1675325779876735),
#  ('0_L',
#   ('Sufficiente_LE',),
#   2199,
#   0.14660977398493233,
#   0.8813627254509018,
#   1.1567692963806506),
#  ('0_L',
#   ('4_NP', 'low_SA', '0_P'),
#   1820,
#   0.12134142276151744,
#   0.8809293320425944,
#   1.1562004770132022),
#  ('0_L',
#   ('4_NP', 'low_SA'),
#   1838,
#   0.12254150276685112,
#   0.8806899856252994,
#   1.1558863400764672),
#  ('0_L',
#   ('Sufficiente_LE', '0_P'),
#   2138,
#   0.14254283618907926,
#   0.8805601317957167,
#   1.1557159097658343),
#  ('0_L',
#   ('Molto soddisfatto_SAT', 'medium_SA'),
#   1632,
#   0.10880725381692113,
#   0.8793103448275862,
#   1.15407559171062),
#  ('0_L',
#   ('Molto soddisfatto_SAT', 'medium_SA', '0_P'),
#   1571,
#   0.10474031602106808,
#   0.8756967670011149,
#   1.1493328498643438),
#  ('0_L',
#   ('Soddisfatto_SAT', 'low_SA', '0_P'),
#   1697,
#   0.1131408760584039,
#   0.8715973292244479,
#   1.1439524274621538),
#  ('0_L',
#   ('Soddisfatto_SAT', 'low_SA'),
#   1708,
#   0.11387425828388559,
#   0.8709841917389087,
#   1.143147697925437),
#  ('0_L',
#   ('Molto soddisfatto_SAT', 'medium_SA', '0_WA'),
#   1363,
#   0.09087272484832322,
#   0.868706182281708,
#   1.1401578603468097),
#  ('0_L',
#   ('Sufficiente_LE', '0_WA'),
#   1814,
#   0.12094139609307288,
#   0.8662846227316141,
#   1.136979616411575),
#  ('0_L',
#   ('4_NP', 'low_SA', '0_WA', '0_P'),
#   1494,
#   0.09960664044269618,
#   0.86558516801854,
#   1.1360615974020023),
#  ('0_L',
#   ('Sufficiente_LE', '0_WA', '0_P'),
#   1762,
#   0.11747449829988665,
#   0.8654223968565815,
#   1.135847963812729),
#  ('0_L',
#   ('4_NP', 'low_SA', '0_WA'),
#   1504,
#   0.10027335155677045,
#   0.8648648648648649,
#   1.135116215270223),
#  ('0_L',
#   ('Molto soddisfatto_SAT', 'medium_SA', '0_WA', '0_P'),
#   1316,
#   0.08773918261217414,
#   0.8646517739816032,
#   1.134836538147538),
#  ('0_L',
#   ('Molto soddisfatto_SAT',),
#   3647,
#   0.24314954330288685,
#   0.8633996212121212,
#   1.1331931150298045),
#  ('0_L',
#   ('Molto soddisfatto_SAT', '4_NP'),
#   1361,
#   0.09073938262550836,
#   0.8630310716550412,
#   1.1327094017985617),
#  ('0_L',
#   ('Molto soddisfatto_SAT', '0_P'),
#   3549,
#   0.236615774384959,
#   0.8603636363636363,
#   1.1292084513316576),
#  ('0_L',
#   ('Molto soddisfatto_SAT', '4_NP', '0_P'),
#   1320,
#   0.08800586705780386,
#   0.8599348534201955,
#   1.1286456830984872),
#  ('0_WA',
#   ('1_L', 'low_SA', '0_P'),
#   2066,
#   0.13774251616774452,
#   0.9573679332715477,
#   1.1192175862151166),
#  ('0_WA',
#   ('1_L', 'low_SA'),
#   2077,
#   0.13847589839322622,
#   0.9562615101289135,
#   1.1179241146082286),
#  ('0_WA',
#   ('2_NP', '1_L', '0_P'),
#   1485,
#   0.09900660044002933,
#   0.954983922829582,
#   1.1164305423632814),
#  ('0_WA',
#   ('1_L', '3_TSC', '0_P'),
#   1500,
#   0.10000666711114074,
#   0.9548058561425843,
#   1.1162223722745614),
#  ('0_WA',
#   ('2_NP', '1_L', '3_TSC', '0_P'),
#   1446,
#   0.09640642709513968,
#   0.9538258575197889,
#   1.1150766981246543),
#  ('0_WA',
#   ('1_L', '0_P'),
#   3387,
#   0.22581505433695578,
#   0.9535472972972973,
#   1.114751045375071),
#  ('0_WA',
#   ('2_NP', '1_L'),
#   1494,
#   0.09960664044269618,
#   0.9534141671984684,
#   1.1145954087147176),
#  ('0_WA',
#   ('1_L', '3_TSC'),
#   1512,
#   0.10080672044802987,
#   0.9533417402269861,
#   1.1145107374641126),
#  ('0_WA',
#   ('1_L',),
#   3402,
#   0.2268151210080672,
#   0.9526743209185102,
#   1.1137304863177502),
#  ('0_L',
#   ('Soddisfatto_SAT', 'low_SA', '0_WA', '0_P'),
#   1394,
#   0.09293952930195347,
#   0.8484479610468655,
#   1.1135693881468267),
#  ('0_WA',
#   ('2_NP', '1_L', '3_TSC'),
#   1455,
#   0.09700646709780653,
#   0.9522251308900523,
#   1.1132053576165155),
#  ('0_L',
#   ('Molto soddisfatto_SAT', '0_WA'),
#   3021,
#   0.20141342756183744,
#   0.8476430976430976,
#   1.1125130225366486),
#  ('0_L',
#   ('Soddisfatto_SAT', 'low_SA', '0_WA'),
#   1399,
#   0.0932728848589906,
#   0.8473652331920049,
#   1.1121483315231782),
#  ('0_L',
#   ('Molto soddisfatto_SAT', '0_WA', '0_P'),
#   2940,
#   0.19601306753783584,
#   0.8440999138673557,
#   1.107862671342008),
#  ('0_WA',
#   ('2_NP', 'Insufficiente_LE', '0_P'),
#   1439,
#   0.09593972931528769,
#   0.9386823222439661,
#   1.097373043751929),
#  ('0_WA',
#   ('2_NP', 'Insufficiente_LE'),
#   1453,
#   0.09687312487499167,
#   0.9326059050064185,
#   1.0902693662658824),
#  ('0_WA',
#   ('2_NP', '3_TSC', '0_P'),
#   1715,
#   0.11434095606373758,
#   0.9325720500271887,
#   1.0902297878688856),
#  ('0_L',
#   ('Molto soddisfatto_SAT', 'low_SA'),
#   1684,
#   0.11227415161010734,
#   0.8303747534516766,
#   1.0898486985493259),
#  ('0_WA',
#   ('2_NP', '3_TSC'),
#   1727,
#   0.11514100940062671,
#   0.9314994606256742,
#   1.0889758698304355),
#  ('0_L',
#   ('sales_D', 'medium_SA'),
#   1469,
#   0.0979398626575105,
#   0.8290067720090294,
#   1.0880532528319418),
#  ('0_L',
#   ('Molto soddisfatto_SAT', 'low_SA', '0_P'),
#   1666,
#   0.11107407160477366,
#   0.8288557213930349,
#   1.0878550022028464),
#  ('0_L',
#   ('sales_D', 'medium_SA', '0_P'),
#   1402,
#   0.09347289819321287,
#   0.8227699530516432,
#   1.079867564387609),
#  ('0_WA',
#   ('2_NP', '0_P'),
#   2144,
#   0.14294286285752383,
#   0.9119523606975755,
#   1.066124197825638),
#  ('0_WA',
#   ('Insufficiente_LE', '3_TSC', '0_P'),
#   2001,
#   0.13340889392626176,
#   0.9091322126306225,
#   1.0628272842748796),
#  ('0_WA',
#   ('Insufficiente_LE', '3_TSC'),
#   2016,
#   0.13440896059737314,
#   0.9081081081081082,
#   1.0616300478186682),
#  ('0_L',
#   ('Molto soddisfatto_SAT', 'low_SA', '0_WA'),
#   1382,
#   0.09213947596506433,
#   0.808187134502924,
#   1.0607279340575215),
#  ('0_WA',
#   ('2_NP',),
#   2166,
#   0.14440962730848722,
#   0.907035175879397,
#   1.060375728995719),
#  ('0_L',
#   ('Molto soddisfatto_SAT', 'low_SA', '0_WA', '0_P'),
#   1365,
#   0.09100606707113808,
#   0.8062610750147667,
#   1.0582000231139732),
#  ('0_WA',
#   ('Insoddisfatto_SAT',),
#   1337,
#   0.08913927595173012,
#   0.8877822045152722,
#   1.0378679100175034),
#  ('0_WA',
#   ('Neutrale_SAT', '3_TSC', '0_P'),
#   1810,
#   0.12067471164744316,
#   0.8794946550048591,
#   1.0281792930957039),
#  ('0_WA',
#   ('141-162_AMH', '3_TSC', '0_P'),
#   1442,
#   0.09613974264950997,
#   0.878732480195003,
#   1.0272882673768395),
#  ('0_WA',
#   ('141-162_AMH', '3_TSC'),
#   1463,
#   0.09753983598906593,
#   0.877624475104979,
#   1.0259929463834434),
#  ('0_WA',
#   ('4_TSC', '0_P'),
#   2213,
#   0.1475431695446363,
#   0.8774781919111816,
#   1.0258219330066884),
#  ('0_WA',
#   ('Neutrale_SAT', '3_TSC'),
#   1832,
#   0.12214147609840656,
#   0.8769746290090953,
#   1.0252332393224801),
#  ('0_WA',
#   ('4_TSC',),
#   2239,
#   0.14927661844122941,
#   0.8756355103637075,
#   1.023667733432989),
#  ('0_WA',
#   ('Neutrale_SAT', 'medium_SA', '0_P'),
#   1323,
#   0.08820588039202613,
#   0.875,
#   1.0229247856586126),
#  ('0_WA',
#   ('sales_D', 'low_SA', '0_P'),
#   1819,
#   0.12127475165011001,
#   0.8749398749398749,
#   1.0228544960423371),
#  ('0_WA',
#   ('sales_D', 'low_SA'),
#   1834,
#   0.12227481832122142,
#   0.873749404478323,
#   1.0214627683375188),
#  ('0_WA',
#   ('Insufficiente_LE', 'low_SA', '0_P'),
#   1590,
#   0.10600706713780919,
#   0.8731466227347611,
#   1.0207580821822824),
#  ('0_WA',
#   ('Neutrale_SAT', 'medium_SA'),
#   1359,
#   0.09060604040269352,
#   0.8722721437740694,
#   1.019735766521221),
#  ('0_WA',
#   ('3_TSC', 'low_SA', '0_P'),
#   2763,
#   0.18421228081872124,
#   0.87078474629688,
#   1.0179969142406002),
#  ('0_P',
#   ('1_L', '0_WA'),
#   3387,
#   0.22581505433695578,
#   0.9955908289241623,
#   1.0172252617870239),
#  ('0_WA',
#   ('Buono_LE', 'low_SA', '0_P'),
#   1695,
#   0.11300753383558904,
#   0.8701232032854209,
#   1.0172235328197996),
#  ('0_WA',
#   ('Insufficiente_LE', 'low_SA'),
#   1598,
#   0.10654043602906861,
#   0.869896570495373,
#   1.0169585861933046),
#  ('0_WA',
#   ('Insufficiente_LE', '0_P'),
#   3080,
#   0.20534702313487566,
#   0.8698107879130189,
#   1.0168583014736845),
#  ('0_P',
#   ('Soddisfatto_SAT', 'low_SA', '0_WA'),
#   1643,
#   0.10954063604240283,
#   0.9951544518473653,
#   1.0167794021293346),
#  ('0_P',
#   ('Insufficiente_LE', 'low_SA', '0_WA'),
#   1590,
#   0.10600706713780919,
#   0.9949937421777222,
#   1.016615200199159),
#  ('0_P',
#   ('2_TSC', 'low_SA'),
#   1519,
#   0.10127341822788186,
#   0.9947609692206941,
#   1.0163773690286915),
#  ('0_P',
#   ('1_L', 'low_SA', '0_WA'),
#   2066,
#   0.13774251616774452,
#   0.994703899855561,
#   1.0163190595322587),
#  ('0_P',
#   ('2_TSC', 'low_SA', '0_L'),
#   1497,
#   0.09980665377691846,
#   0.9946843853820598,
#   1.016299121004463),
#  ('0_P',
#   ('1_L',),
#   3552,
#   0.23681578771918127,
#   0.9946793615233828,
#   1.0162939879761048),
#  ('0_WA',
#   ('sales_D', '3_TSC', '0_P'),
#   1496,
#   0.09973998266551104,
#   0.8687572590011614,
#   1.015626666232145),
#  ('0_WA',
#   ('3_TSC', 'low_SA'),
#   2784,
#   0.18561237415827722,
#   0.8686427457098284,
#   1.0154927936790115),
#  ('0_WA',
#   ('Neutrale_SAT', '0_P'),
#   3066,
#   0.20441362757517167,
#   0.8685552407932011,
#   1.0153904954526285),
#  ('0_P',
#   ('Soddisfatto_SAT', 'low_SA', '0_L'),
#   1697,
#   0.1131408760584039,
#   0.9935597189695551,
#   1.0151500153150106),
#  ('0_P',
#   ('1_L', 'low_SA'),
#   2158,
#   0.14387625841722781,
#   0.9935543278084714,
#   1.0151445070026746),
#  ('0_P',
#   ('4_NP', 'low_SA', '0_L', '0_WA'),
#   1494,
#   0.09960664044269618,
#   0.9933510638297872,
#   1.0149368260478868),
#  ('0_WA',
#   ('Buono_LE', 'low_SA'),
#   1709,
#   0.11394092939529302,
#   0.8679532757745049,
#   1.0146867640952297),
#  ('0_P',
#   ('2_NP', '3_TSC', '0_WA'),
#   1715,
#   0.11434095606373758,
#   0.9930515344528084,
#   1.014630787824092),
#  ('0_P',
#   ('3_TSC', 'low_SA', '0_L', '0_WA'),
#   1830,
#   0.1220081338755917,
#   0.9929462832338578,
#   1.014523249470343),
#  ('0_P',
#   ('Soddisfatto_SAT', 'low_SA'),
#   1947,
#   0.1298086539102607,
#   0.9928607853136155,
#   1.014435893659327),
#  ('0_WA',
#   ('Ottimo_LE', '0_P'),
#   2274,
#   0.15161010734048935,
#   0.867607783288821,
#   1.01428286372167),
#  ('0_P',
#   ('Insufficiente_LE', '3_TSC', '0_WA'),
#   2001,
#   0.13340889392626176,
#   0.9925595238095238,
#   1.0141280856688724),
#  ('0_P',
#   ('4_NP', 'low_SA', '0_WA'),
#   1726,
#   0.11507433828921929,
#   0.99252443933295,
#   1.014092238798019),
#  ('0_P',
#   ('3_TSC', 'low_SA', '0_WA'),
#   2763,
#   0.18421228081872124,
#   0.9924568965517241,
#   1.0140232282955934),
#  ('0_P',
#   ('low_SA', '0_WA'),
#   6228,
#   0.4152276818454564,
#   0.9923518164435946,
#   1.0139158647709452),
#  ('0_P',
#   ('2_NP', '1_L'),
#   1555,
#   0.10367357823854924,
#   0.99234205488194,
#   1.013905891088162),
#  ('0_P',
#   ('2_NP', '1_L', '3_TSC'),
#   1516,
#   0.10107340489365958,
#   0.9921465968586387,
#   1.0137061857140819),
#  ('0_P',
#   ('1_L', '3_TSC', '0_WA'),
#   1500,
#   0.10000666711114074,
#   0.9920634920634921,
#   1.0136212750313567),
#  ('0_P',
#   ('2_NP', '3_TSC'),
#   1839,
#   0.12260817387825855,
#   0.9919093851132686,
#   1.013463819299313),
#  ('0_P',
#   ('sales_D', 'low_SA', '0_WA'),
#   1819,
#   0.12127475165011001,
#   0.9918211559432933,
#   1.0133736728878378),
#  ('0_P',
#   ('Buono_LE', 'low_SA', '0_WA'),
#   1695,
#   0.11300753383558904,
#   0.9918080748976009,
#   1.0133603075878144),
#  ('0_P',
#   ('support_D', '0_WA'),
#   1868,
#   0.12454163610907394,
#   0.9915074309978769,
#   1.013053130622422),
#  ('0_P',
#   ('Insufficiente_LE', '3_TSC'),
#   2201,
#   0.1467431162077472,
#   0.9914414414414414,
#   1.0129857070967425),
#  ('0_P',
#   ('Insufficiente_LE', 'low_SA'),
#   1821,
#   0.12140809387292487,
#   0.9912901469787697,
#   1.0128311249682949),
#  ('0_P',
#   ('low_SA', '0_L', '0_WA'),
#   4162,
#   0.27748516567771186,
#   0.9911883781852822,
#   1.0127271447139679),
#  ('0_P',
#   ('Molto soddisfatto_SAT', 'low_SA'),
#   2010,
#   0.1340089339289286,
#   0.9911242603550295,
#   1.01266163358754),
#  ('0_P',
#   ('support_D',),
#   2209,
#   0.1472764850990066,
#   0.9910273665320771,
#   1.0125626342380536),
#  ('0_P',
#   ('low_SA',),
#   7250,
#   0.4833655577038469,
#   0.990978676872608,
#   1.0125128865403439),
#  ('0_WA',
#   ('Insufficiente_LE',),
#   3123,
#   0.20821388092539503,
#   0.8658164679789299,
#   1.0121887142023358),
#  ('0_P',
#   ('1_L', '3_TSC'),
#   1571,
#   0.10474031602106808,
#   0.9905422446406053,
#   1.0120669705289127),
#  ('0_P',
#   ('3_TSC', 'low_SA', '0_L'),
#   2198,
#   0.1465431028735249,
#   0.9905362776025236,
#   1.0120608738256303),
#  ('0_P',
#   ('sales_D', 'low_SA'),
#   2079,
#   0.13860924061604107,
#   0.9904716531681753,
#   1.0119948450864755),
#  ('0_WA',
#   ('229-250_AMH', '0_P'),
#   1739,
#   0.11594106273751584,
#   0.8656047784967645,
#   1.0119412371529986),
#  ('0_P',
#   ('4_NP', 'low_SA', '0_L'),
#   1820,
#   0.12134142276151744,
#   0.9902067464635473,
#   1.0117241818941924),
#  ('0_P',
#   ('technical_D', '0_WA'),
#   2316,
#   0.1544102940196013,
#   0.990166737922189,
#   1.0116833039574191),
#  ('0_P',
#   ('Molto soddisfatto_SAT', 'low_SA', '0_WA'),
#   1693,
#   0.11287419161277419,
#   0.9900584795321637,
#   1.0115726930860303),
#  ('0_P',
#   ('3_TSC', 'low_SA'),
#   3173,
#   0.21154743649576638,
#   0.9900156006240249,
#   1.0115288824087023),
#  ('0_P',
#   ('4_NP', 'low_SA'),
#   2066,
#   0.13774251616774452,
#   0.9899377096310493,
#   1.011449298825348),
#  ('0_P',
#   ('low_SA', '0_L'),
#   5092,
#   0.3394892992866191,
#   0.9898911353032659,
#   1.0114017124260004),
#  ('0_P',
#   ('support_D', '0_L'),
#   1657,
#   0.11047403160210681,
#   0.9898446833930705,
#   1.011354251104405),
#  ('0_P',
#   ('2_NP', '0_WA'),
#   2144,
#   0.14294286285752383,
#   0.989843028624192,
#   1.011352560376993),
#  ('0_P',
#   ('technical_D',),
#   2692,
#   0.17947863190879393,
#   0.9897058823529412,
#   1.0112124338836352),
#  ('0_WA',
#   ('sales_D', '3_TSC'),
#   1529,
#   0.10194012934195613,
#   0.8648190045248869,
#   1.0110226226709882),
#  ('0_P',
#   ('Buono_LE', 'low_SA'),
#   1948,
#   0.1298753250216681,
#   0.98933468765871,
#   1.0108331730376696),
#  ('0_P',
#   ('Molto soddisfatto_SAT', 'low_SA', '0_L'),
#   1666,
#   0.11107407160477366,
#   0.9893111638954869,
#   1.010809138097303),
#  ('0_WA',
#   ('Ottimo_LE',),
#   2312,
#   0.1541436095739716,
#   0.8642990654205608,
#   1.01041478427459),
#  ('0_WA',
#   ('Neutrale_SAT',),
#   3129,
#   0.20861390759383958,
#   0.8641259320629661,
#   1.0102123815286381),
#  ('0_WA',
#   ('Buono_LE', '0_P'),
#   3389,
#   0.22594839655977064,
#   0.8640999490056094,
#   1.010182005856207),
#  ('0_P',
#   ('4_TSC', '0_WA'),
#   2213,
#   0.1475431695446363,
#   0.9883876730683341,
#   1.009865579588007),
#  ('0_P',
#   ('Neutrale_SAT', 'low_SA', '0_WA'),
#   1491,
#   0.0994066271084739,
#   0.9880715705765407,
#   1.0095426081115486),
#  ('0_P',
#   ('technical_D', '0_L', '0_WA'),
#   1655,
#   0.11034068937929195,
#   0.9880597014925373,
#   1.0095304811094392),
#  ('0_P',
#   ('Neutrale_SAT', '3_TSC', '0_WA'),
#   1810,
#   0.12067471164744316,
#   0.9879912663755459,
#   1.009460558880573),
#  ('0_WA',
#   ('Insufficiente_LE', 'medium_SA'),
#   1301,
#   0.08673911594106273,
#   0.8633045786330458,
#   1.0092521726357797),
#  ('0_WA',
#   ('3_TSC', '0_P'),
#   5446,
#   0.3630908727248483,
#   0.8632112854652084,
#   1.0091431076143929),
#  ('0_P',
#   ('technical_D', '0_L'),
#   1998,
#   0.13320888059203947,
#   0.9876421156697973,
#   1.009103821044366),
#  ('0_WA',
#   ('Neutrale_SAT', 'low_SA', '0_P'),
#   1491,
#   0.0994066271084739,
#   0.8628472222222222,
#   1.0087174969689097),
#  ('0_WA',
#   ('229-250_AMH',),
#   1772,
#   0.11814120941396093,
#   0.8627069133398247,
#   1.0085534679021069),
#  ('0_WA',
#   ('Buono_LE', 'medium_SA', '0_P'),
#   1418,
#   0.09453963597573171,
#   0.8625304136253041,
#   1.00834712969337),
#  ('0_WA',
#   ('251-272_AMH', '0_P'),
#   1879,
#   0.12527501833455565,
#   0.8623221661312529,
#   1.00810367652398),
#  ('0_P',
#   ('4_TSC',),
#   2522,
#   0.1681445429695313,
#   0.986312084473993,
#   1.007744887944511),
#  ('0_P',
#   ('Insufficiente_LE', '0_WA'),
#   3080,
#   0.20534702313487566,
#   0.9862311879602946,
#   1.0076622335297316),
#  ('0_WA',
#   ('sales_D', '0_P'),
#   3482,
#   0.23214880992066136,
#   0.8618811881188119,
#   1.0075881481367155),
#  ('0_P',
#   ('Insoddisfatto_SAT',),
#   1485,
#   0.09900660044002933,
#   0.9860557768924303,
#   1.0074830107363462),
#  ('0_P',
#   ('3_NP', 'low_SA'),
#   1766,
#   0.11774118274551637,
#   0.9860413176996091,
#   1.0074682373417192),
#  ('0_P',
#   ('3_NP', 'low_SA', '0_L'),
#   1729,
#   0.11527435162344156,
#   0.9857468643101482,
#   1.007167385407896),
#  ('0_P',
#   ('Buono_LE', '0_WA'),
#   3389,
#   0.22594839655977064,
#   0.9854608897935446,
#   1.0068751965949165),
#  ('0_WA',
#   ('3_TSC',),
#   5548,
#   0.3698913260884059,
#   0.8610895545553313,
#   1.006662683458723),
#  ('0_P',
#   ('Neutrale_SAT', '3_TSC'),
#   2058,
#   0.1372091472764851,
#   0.9851603638104356,
#   1.0065681401084963),
#  ('0_P',
#   ('2_NP',),
#   2351,
#   0.15674378291886126,
#   0.9845058626465661,
#   1.0058994164738315),
#  ('0_P',
#   ('141-162_AMH', '3_TSC'),
#   1641,
#   0.10940729381958797,
#   0.9844031193761248,
#   1.0057944405669275),
#  ('0_WA',
#   ('technical_D', '0_P'),
#   2316,
#   0.1544102940196013,
#   0.8603268945022289,
#   1.005771090462894),
#  ('0_WA',
#   ('Buono_LE',),
#   3439,
#   0.22928195213014202,
#   0.859964991247812,
#   1.0053480049669472),
#  ('0_P',
#   ('2_NP', 'Insufficiente_LE'),
#   1533,
#   0.10220681378758584,
#   0.9839537869062901,
#   1.0053353439923327),
#  ('0_WA',
#   ('technical_D',),
#   2339,
#   0.15594372958197214,
#   0.8599264705882353,
#   1.0053029721241575),
#  ('0_P',
#   ('2_TSC', '0_WA'),
#   2642,
#   0.17614507633842255,
#   0.9836187639612807,
#   1.0049930409165702),
#  ('0_P',
#   ('Ottimo_LE', '0_WA'),
#   2274,
#   0.15161010734048935,
#   0.9835640138408305,
#   1.004937101062576),
#  ('0_P',
#   ('Neutrale_SAT', 'low_SA'),
#   1728,
#   0.11520768051203413,
#   0.983494593056346,
#   1.0048661717474205),
#  ('0_P',
#   ('2_TSC',),
#   3190,
#   0.21268084538969265,
#   0.9833538840937115,
#   1.0047224051445216),
#  ('0_P',
#   ('2_TSC', '0_L', '0_WA'),
#   2590,
#   0.17267817854523634,
#   0.9832953682611997,
#   1.0046626177486195),
#  ('0_P',
#   ('2_TSC', '0_L'),
#   3137,
#   0.209147276485099,
#   0.9830774052021309,
#   1.0044399182988257),
#  ('0_WA',
#   ('low_SA', '0_P'),
#   6228,
#   0.4152276818454564,
#   0.8590344827586207,
#   1.0042601875991077),
#  ('0_P',
#   ('251-272_AMH', '0_WA'),
#   1879,
#   0.12527501833455565,
#   0.9827405857740585,
#   1.0040957797019825),
#  ('0_WA',
#   ('Neutrale_SAT', 'low_SA'),
#   1509,
#   0.10060670711380759,
#   0.85885031303358,
#   1.0040448827116653),
#  ('0_WA',
#   ('141-162_AMH', '0_P'),
#   2245,
#   0.149676645109674,
#   0.858508604206501,
#   1.0036454056502968),
#  ('0_P',
#   ('5_NP', '0_WA'),
#   2303,
#   0.15354356957130474,
#   0.982089552238806,
#   1.003430599048355),
#  ('0_P',
#   ('141-162_AMH', '0_WA'),
#   2245,
#   0.149676645109674,
#   0.9820647419072616,
#   1.0034052495822219),
#  ('0_WA',
#   ('3_TSC', 'medium_SA', '0_P'),
#   2265,
#   0.15101006733782252,
#   0.8582796513830997,
#   1.0033777467728069),
#  ('0_WA',
#   ('sales_D',),
#   3553,
#   0.2368824588305887,
#   0.8582125603864734,
#   1.0032993135804142),
#  ('0_P',
#   ('5_NP',),
#   2711,
#   0.18074538302553503,
#   0.9818906193408186,
#   1.0032273432897096),
#  ('0_P',
#   ('Insufficiente_LE',),
#   3541,
#   0.23608240549369958,
#   0.9817022456334904,
#   1.0030348761755261),
#  ('0_P',
#   ('3_TSC', '0_WA'),
#   5446,
#   0.3630908727248483,
#   0.9816149963950973,
#   1.0029457309897865),
#  ('0_WA',
#   ('low_SA',),
#   6276,
#   0.4184278951930129,
#   0.8578458173865501,
#   1.002870570146599),
#  ('0_WA',
#   ('251-272_AMH',),
#   1912,
#   0.12747516501100073,
#   0.857783759533423,
#   1.0027980209853322),
#  ('0_P',
#   ('229-250_AMH', '0_WA'),
#   1739,
#   0.11594106273751584,
#   0.9813769751693002,
#   1.0027025375043825),
#  ('0_P',
#   ('Buono_LE', '0_L', '0_WA'),
#   2447,
#   0.16314420961397427,
#   0.9811547714514836,
#   1.0024755052452863),
#  ('0_P',
#   ('0_WA',),
#   12587,
#   0.8391892792852856,
#   0.9810600155884646,
#   1.0023786903141267),
#  ('0_WA',
#   ('0_P',),
#   12587,
#   0.8391892792852856,
#   0.857425068119891,
#   1.0023786903141267),
#  ('0_WA',
#   ('medium_SA', '0_P'),
#   5371,
#   0.3580905393692913,
#   0.8573024740622506,
#   1.002235370885401),
#  ('0_P',
#   ('4_TSC', '0_L'),
#   1635,
#   0.10900726715114341,
#   0.9808038392321535,
#   1.0021169471827704),
#  ('0_P',
#   ('Buono_LE',),
#   3922,
#   0.26148409893992935,
#   0.9807451862965741,
#   1.0020570197045173),
#  ('0_WA',
#   ('141-162_AMH',),
#   2286,
#   0.1524101606773785,
#   0.8571428571428571,
#   1.0020487696247633),
#  ('0_P',
#   ('Soddisfatto_SAT', '0_WA'),
#   3459,
#   0.23061537435829055,
#   0.980720158775163,
#   1.0020314483289285),
#  ('0_P',
#   ('141-162_AMH',),
#   2615,
#   0.17434495633042202,
#   0.9805024371953506,
#   1.0018089956057945),
#  ('0_WA',
#   ('Buono_LE', 'medium_SA'),
#   1443,
#   0.09620641376091739,
#   0.8568883610451307,
#   1.0017512492062288),
#  ('0_P',
#   ('185-206_AMH',),
#   1652,
#   0.11014067604506968,
#   0.9804154302670623,
#   1.0017200979956178),
#  ('0_P',
#   ('3_NP', '3_TSC'),
#   1747,
#   0.11647443162877526,
#   0.9803591470258137,
#   1.0016625917057342),
#  ('0_P',
#   ('3_NP', '3_TSC', '0_L'),
#   1738,
#   0.11587439162610841,
#   0.9802594472645234,
#   1.0015607254441816),
#  ('0_P',
#   ('163-184_AMH', '0_WA'),
#   1473,
#   0.09820654710314021,
#   0.9800399201596807,
#   1.0013364279615156),
#  ('0_P',
#   ('185-206_AMH', '0_L'),
#   1620,
#   0.108007200480032,
#   0.9800362976406534,
#   1.0013327267242615),
#  ('0_P',
#   ('sales_D', '0_WA'),
#   3482,
#   0.23214880992066136,
#   0.9800168871376301,
#   1.0013128944262477),
#  ('0_P',
#   ('Neutrale_SAT', '0_WA'),
#   3066,
#   0.20441362757517167,
#   0.9798657718120806,
#   1.0011584953276156),
#  ('0_P',
#   ('Insufficiente_LE', '0_L', '0_WA'),
#   1800,
#   0.1200080005333689,
#   0.979858464888405,
#   1.0011510296226966),
#  ('0_P',
#   ('Ottimo_LE',),
#   2621,
#   0.1747449829988666,
#   0.9798130841121495,
#   1.0011046627110443),
#  ('0_P',
#   ('163-184_AMH',),
#   1742,
#   0.11614107607173811,
#   0.9797525309336333,
#   1.0010427936971094),
#  ('0_WA',
#   ('3_TSC', 'medium_SA'),
#   2327,
#   0.15514367624508302,
#   0.8561442236938925,
#   1.000881310302782),
#  ('0_P',
#   ('Soddisfatto_SAT', '0_L', '0_WA'),
#   3077,
#   0.20514700980065337,
#   0.9793125397835774,
#   1.0005932414314629),
#  ('0_P',
#   ('163-184_AMH', '0_L'),
#   1701,
#   0.1134075605040336,
#   0.9792746113989638,
#   1.0005544888537505),
#  ('0_P',
#   ('3_TSC',),
#   6309,
#   0.42062804186945796,
#   0.9792022349837033,
#   1.0004805396812373),
#  ('0_P',
#   ('Insufficiente_LE', 'medium_SA'),
#   1475,
#   0.09833988932595507,
#   0.9787657597876576,
#   1.0000345797721442),
#  ('0_P',
#   ('sales_D', '3_TSC', '0_WA'),
#   1496,
#   0.09973998266551104,
#   0.9784172661870504,
#   0.9996785133201341),
#  ('0_P',
#   ('229-250_AMH',),
#   2009,
#   0.13394226281752117,
#   0.9780915287244402,
#   0.9993456975025802),
#  ('0_P',
#   ('3_NP', '0_WA'),
#   3271,
#   0.21808120541369425,
#   0.9778774289985053,
#   0.9991269453370968),
#  ('0_WA',
#   ('medium_SA',),
#   5509,
#   0.36729115274351626,
#   0.8546385355259075,
#   0.9991210751639195),
#  ('0_P',
#   ('Soddisfatto_SAT',),
#   4145,
#   0.2763517567837856,
#   0.9778249587166785,
#   0.9990733348631785),
#  ('0_P',
#   ('3_TSC', '0_L', '0_WA'),
#   3946,
#   0.2630842056137076,
#   0.9777006937561943,
#   0.9989463695946292),
#  ('0_P',
#   ('251-272_AMH',),
#   2179,
#   0.14527635175678377,
#   0.9775684163301929,
#   0.9988112177477223),
#  ('0_P',
#   ('3_NP', '0_L', '0_WA'),
#   3200,
#   0.2133475565037669,
#   0.9773976786805131,
#   0.9986367699270448),
#  ('0_P',
#   ('Molto soddisfatto_SAT', '0_WA'),
#   3483,
#   0.2322154810320688,
#   0.9772727272727273,
#   0.9985091032945257),
#  ('0_WA',
#   ('4_NP', 'medium_SA', '0_P'),
#   1569,
#   0.10460697379825322,
#   0.854109961894393,
#   0.9985031425139518),
#  ('0_P',
#   ('5_NP', '0_L'),
#   2099,
#   0.1399426628441896,
#   0.9767333643555142,
#   0.9979580198888527),
#  ('0_P',
#   ('3_NP', 'medium_SA', '0_WA'),
#   1504,
#   0.10027335155677045,
#   0.9766233766233766,
#   0.9978456420963233),
#  ('0_P',
#   ('3_NP',),
#   3960,
#   0.26401760117341155,
#   0.9765721331689272,
#   0.9977932851090422),
#  ('0_P',
#   ('Molto soddisfatto_SAT',),
#   4125,
#   0.27501833455563707,
#   0.9765625,
#   0.9977834426089919),
#  ('0_P',
#   ('Soddisfatto_SAT', '3_TSC', '0_L'),
#   1700,
#   0.11334088939262618,
#   0.9764503159103963,
#   0.99766882073161),
#  ('0_P',
#   ('Soddisfatto_SAT', '0_L'),
#   3750,
#   0.25001666777785186,
#   0.9763082530590992,
#   0.9975236708197158),
#  ('0_P',
#   ('Buono_LE', 'medium_SA'),
#   1644,
#   0.10960730715381026,
#   0.9762470308788599,
#   0.9974611182664863),
#  ('0_P',
#   ('5_NP', '0_L', '0_WA'),
#   1720,
#   0.11467431162077472,
#   0.9761634506242906,
#   0.9973757217924887),
#  ('0_P',
#   ('3_NP', '0_L'),
#   3888,
#   0.2592172811520768,
#   0.9761486316846598,
#   0.9973605808336657),
#  ('0_P',
#   ('3_NP', 'medium_SA', '0_L', '0_WA'),
#   1472,
#   0.09813987599173278,
#   0.9761273209549072,
#   0.9973388070165294),
#  ('0_P',
#   ('sales_D',),
#   4040,
#   0.2693512900860057,
#   0.9758454106280193,
#   0.9970507707091051),
#  ('0_P',
#   ('0_L', '0_WA'),
#   9200,
#   0.6133742249483299,
#   0.9758167161646161,
#   0.9970214527079752),
#  ('0_P',
#   ('3_NP', 'medium_SA'),
#   1811,
#   0.12074138275885059,
#   0.9757543103448276,
#   0.9969576907944189),
#  ('0_P',
#   ('3_TSC', '0_L'),
#   4738,
#   0.31588772584838987,
#   0.9754992793905704,
#   0.996697117954984),
#  ('0_P',
#   ('Buono_LE', '0_L'),
#   2930,
#   0.19534635642376158,
#   0.9753661784287616,
#   0.9965611246766346),
#  ('0_P',
#   ('3_NP', 'medium_SA', '0_L'),
#   1779,
#   0.11860790719381292,
#   0.975328947368421,
#   0.9965230845762225),
#  ('0_P',
#   ('Discreto_LE',),
#   2168,
#   0.14454296953130208,
#   0.9752586594691858,
#   0.9964512693037001),
#  ('0_P',
#   ('Soddisfatto_SAT', '3_TSC'),
#   1719,
#   0.1146076405093673,
#   0.9750425411230856,
#   0.9962304546529401),
#  ('0_P',
#   ('4_NP', '0_WA'),
#   3590,
#   0.23934928995266352,
#   0.9750135795763172,
#   0.9962008637646582),
#  ('0_P',
#   ('medium_SA', '0_WA'),
#   5371,
#   0.3580905393692913,
#   0.9749500816845162,
#   0.9961359860480967),
#  ('0_P',
#   ('Neutrale_SAT', '0_L', '0_WA'),
#   2101,
#   0.14007600506700446,
#   0.9749419953596288,
#   0.9961277240053864),
#  ('0_P',
#   ('141-162_AMH', '0_L'),
#   1670,
#   0.11134075605040336,
#   0.9748978400467017,
#   0.9960826091866811),
#  ('0_P',
#   ('Neutrale_SAT',),
#   3530,
#   0.23534902326821788,
#   0.9748688207677437,
#   0.9960529593116749),
#  ('0_P',
#   ('Insufficiente_LE', '0_L'),
#   2202,
#   0.14680978731915462,
#   0.9747675962815405,
#   0.9959495351925631),
#  ('0_P',
#   ('Discreto_LE', '0_L'),
#   2110,
#   0.14067604506967132,
#   0.9745958429561201,
#   0.995774049625262),
#  ('0_WA',
#   ('4_NP', 'medium_SA'),
#   1626,
#   0.10840722714847656,
#   0.8513089005235602,
#   0.9952285423969509),
#  ('0_P',
#   ('Soddisfatto_SAT', 'medium_SA', '0_WA'),
#   1499,
#   0.09993999599973331,
#   0.9740090968161144,
#   0.9951745533477452),
#  ('0_P',
#   ('sales_D', '3_TSC'),
#   1722,
#   0.11480765384358957,
#   0.9739819004524887,
#   0.9951467660004685),
#  ('0_P',
#   ('0_L',),
#   11128,
#   0.7419161277418495,
#   0.9737486874343717,
#   0.9949084852062766),
#  ('0_P',
#   ('sales_D', '0_L', '0_WA'),
#   2517,
#   0.16781118741249418,
#   0.9736943907156673,
#   0.9948530086065596),
#  ('0_P',
#   ('Molto soddisfatto_SAT', '4_NP'),
#   1535,
#   0.1023401560104007,
#   0.9733671528218135,
#   0.9945186597530232),
#  ('0_P',
#   ('3_TSC', 'medium_SA', '0_WA'),
#   2265,
#   0.15101006733782252,
#   0.9733562526858617,
#   0.994507522754444),
#  ('0_P',
#   ('4_NP',),
#   4248,
#   0.2832188812587506,
#   0.9731958762886598,
#   0.9943436613388017),
#  ('0_P',
#   ('Molto soddisfatto_SAT', '0_L', '0_WA'),
#   2940,
#   0.19601306753783584,
#   0.9731876861966237,
#   0.9943352932740571),
#  ('0_P',
#   ('Sufficiente_LE',),
#   2428,
#   0.16187745849723315,
#   0.9731462925851704,
#   0.9942930001692759),
#  ('0_P',
#   ('Molto soddisfatto_SAT', '0_L'),
#   3549,
#   0.236615774384959,
#   0.9731285988483686,
#   0.9942749219432343),
#  ('0_P',
#   ('4_NP', '0_L', '0_WA'),
#   3211,
#   0.2140809387292486,
#   0.973030303030303,
#   0.994174490132937),
#  ('0_P',
#   ('Sufficiente_LE', '0_WA'),
#   2036,
#   0.1357423828255217,
#   0.9723018147086915,
#   0.9934301715814485),
#  ('0_P',
#   ('Sufficiente_LE', '0_L'),
#   2138,
#   0.14254283618907926,
#   0.9722601182355616,
#   0.9933875690337322),
#  ('0_WA',
#   ('5_NP', '0_P'),
#   2303,
#   0.15354356957130474,
#   0.849502028771671,
#   0.9931162065117921),
#  ('0_P',
#   ('medium_SA',),
#   6265,
#   0.4176945129675312,
#   0.9719205708966802,
#   0.9930406432479091),
#  ('0_WA',
#   ('5_NP',),
#   2345,
#   0.1563437562504167,
#   0.8493299529156103,
#   0.9929150400453031),
#  ('0_P',
#   ('229-250_AMH', '0_L'),
#   1536,
#   0.10240682712180812,
#   0.9715370018975332,
#   0.9926487392003475),
#  ('0_P',
#   ('Soddisfatto_SAT', '4_NP'),
#   1500,
#   0.10000666711114074,
#   0.9715025906735751,
#   0.992613580212054),
#  ('0_P',
#   ('4_NP', '0_L'),
#   3843,
#   0.2562170811387426,
#   0.9714357937310415,
#   0.9925453317555784),
#  ('0_P',
#   ('Sufficiente_LE', '0_L', '0_WA'),
#   1762,
#   0.11747449829988665,
#   0.9713340683572216,
#   0.9924413958644391),
#  ('0_P',
#   ('Soddisfatto_SAT', 'medium_SA'),
#   1819,
#   0.12127475165011001,
#   0.9711692471970101,
#   0.992272993099997),
#  ('0_P',
#   ('Discreto_LE', '0_WA'),
#   1808,
#   0.12054136942462831,
#   0.9709989258861439,
#   0.9920989706652774),
#  ('0_P',
#   ('207-228_AMH',),
#   1706,
#   0.11374091606107074,
#   0.970973249857712,
#   0.9920727366904512),
#  ('0_P',
#   ('3_TSC', 'medium_SA'),
#   2639,
#   0.1759450630042003,
#   0.97093451066961,
#   0.9920331556902916),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', 'medium_SA', '0_P'),
#   1522,
#   0.10147343156210414,
#   0.8483835005574136,
#   0.9918085833874237),
#  ('0_P',
#   ('Ottimo_LE', '0_L'),
#   1748,
#   0.11654110274018267,
#   0.9705719044975014,
#   0.9916626699971406),
#  ('0_P',
#   ('Neutrale_SAT', 'medium_SA'),
#   1512,
#   0.10080672044802987,
#   0.9704749679075738,
#   0.9915636269513419),
#  ('0_P',
#   ('sales_D', '0_L'),
#   3033,
#   0.2022134808987266,
#   0.9702495201535508,
#   0.9913332801623371),
#  ('0_P',
#   ('Discreto_LE', '0_L', '0_WA'),
#   1753,
#   0.11687445829721982,
#   0.9701162147205312,
#   0.9911970779695674),
#  ('0_P',
#   ('Molto soddisfatto_SAT', 'medium_SA', '0_WA'),
#   1522,
#   0.10147343156210414,
#   0.9700446144040791,
#   0.99112392176068),
#  ('0_P',
#   ('Molto soddisfatto_SAT', '3_TSC'),
#   1618,
#   0.10787385825721715,
#   0.9700239808153477,
#   0.9911028397990055),
#  ('0_P',
#   ('Molto soddisfatto_SAT', '3_TSC', '0_L'),
#   1613,
#   0.10754050270018001,
#   0.9699338544798557,
#   0.9910107549961413),
#  ('0_WA',
#   ('4_NP', 'medium_SA', '0_L', '0_P'),
#   1424,
#   0.09493966264417628,
#   0.8476190476190476,
#   0.9909148944067104),
#  ('0_P',
#   ('Neutrale_SAT', '0_L'),
#   2512,
#   0.16747783185545703,
#   0.9695098417599383,
#   0.9905775283758388),
#  ('0_P',
#   ('251-272_AMH', '0_L'),
#   1548,
#   0.10320688045869725,
#   0.9693174702567313,
#   0.9903809765926916),
#  ('0_P',
#   ('Soddisfatto_SAT', 'medium_SA', '0_L'),
#   1683,
#   0.11220748049869991,
#   0.9689119170984456,
#   0.9899666106648219),
#  ('0_P',
#   ('medium_SA', '0_L', '0_WA'),
#   4132,
#   0.27548503233548904,
#   0.9685888420065635,
#   0.989636515071965),
#  ('0_WA',
#   ('sales_D', 'medium_SA', '0_P'),
#   1442,
#   0.09613974264950997,
#   0.846244131455399,
#   0.989307539181569),
#  ('0_P',
#   ('3_TSC', 'medium_SA', '0_L', '0_WA'),
#   1744,
#   0.11627441829455297,
#   0.9678135405105438,
#   0.9888443660843084),
#  ('0_WA',
#   ('support_D', '0_P'),
#   1868,
#   0.12454163610907394,
#   0.8456315074694432,
#   0.9885913468849711),
#  ('0_WA',
#   ('163-184_AMH', '0_P'),
#   1473,
#   0.09820654710314021,
#   0.8455797933409873,
#   0.9885308901263811),
#  ('0_P',
#   ('207-228_AMH', '0_L'),
#   1518,
#   0.10120674711647443,
#   0.9674952198852772,
#   0.9885191282737925),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', 'medium_SA'),
#   1569,
#   0.10460697379825322,
#   0.8453663793103449,
#   0.9882813969817508),
#  ('0_WA',
#   ('163-184_AMH',),
#   1503,
#   0.10020668044536303,
#   0.8453318335208099,
#   0.9882410109882017),
#  ('0_WA',
#   ('4_NP', 'medium_SA', '0_L'),
#   1481,
#   0.09873991599439963,
#   0.8453196347031964,
#   0.9882267498763244),
#  ('0_WA',
#   ('support_D',),
#   1884,
#   0.12560837389159277,
#   0.845222072678331,
#   0.988112694318183),
#  ('0_WA',
#   ('4_NP', '0_P'),
#   3590,
#   0.23934928995266352,
#   0.8451035781544256,
#   0.9879741674776484),
#  ('0_P',
#   ('4_NP', '3_TSC', '0_WA'),
#   1461,
#   0.09740649376625109,
#   0.9669093315684977,
#   0.987920508460211),
#  ('0_P',
#   ('Molto soddisfatto_SAT', 'medium_SA'),
#   1794,
#   0.11960797386492433,
#   0.9665948275862069,
#   0.9875991702292587),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '0_P'),
#   3483,
#   0.2322154810320688,
#   0.8443636363636363,
#   0.9871091334230851),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '4_NP'),
#   1331,
#   0.08873924928328555,
#   0.844007609384908,
#   0.9866929176277659),
#  ('0_P',
#   ('medium_SA', '0_L'),
#   4953,
#   0.33022201480098673,
#   0.9656853187755898,
#   0.9866698975691466),
#  ('0_P',
#   ('4_NP', '3_TSC', '0_L'),
#   1713,
#   0.11420761384092273,
#   0.9656144306651635,
#   0.9865974690426966),
#  ('0_WA',
#   ('Soddisfatto_SAT', 'low_SA', '0_P'),
#   1643,
#   0.10954063604240283,
#   0.8438623523369286,
#   0.9865231038738576),
#  ('0_WA',
#   ('Molto soddisfatto_SAT',),
#   3564,
#   0.2376158410560704,
#   0.84375,
#   0.9863917575993765),
#  ('0_P',
#   ('3_TSC', 'medium_SA', '0_L'),
#   2089,
#   0.13927595173011534,
#   0.9653419593345656,
#   0.9863190768432664),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '4_NP', '0_P'),
#   1295,
#   0.08633908927261817,
#   0.8436482084690554,
#   0.9862727575079783),
#  ('0_WA',
#   ('4_NP',),
#   3682,
#   0.24548303220214682,
#   0.8435280641466208,
#   0.9861323019590932),
#  ('0_P',
#   ('1_WA',),
#   2093,
#   0.13954263617574506,
#   0.9649608114338405,
#   0.9859296465051889),
#  ('0_P',
#   ('4_NP', 'medium_SA', '0_WA'),
#   1569,
#   0.10460697379825322,
#   0.9649446494464945,
#   0.9859131333138944),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', 'low_SA'),
#   1710,
#   0.11400760050670045,
#   0.8431952662721893,
#   0.9857432423083841),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '3_TSC', '0_L', '0_P'),
#   1360,
#   0.09067271151410095,
#   0.8431494110353379,
#   0.9856896349274382),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '3_TSC', '0_P'),
#   1364,
#   0.09093939595973065,
#   0.8430160692212608,
#   0.9855337507599136),
#  ('0_P',
#   ('4_NP', '3_TSC'),
#   1734,
#   0.1156077071804787,
#   0.96440489432703,
#   0.985361649183319),
#  ('0_WA',
#   ('Soddisfatto_SAT', '4_NP', '0_P'),
#   1264,
#   0.08427228481898794,
#   0.8426666666666667,
#   0.9851252792933229),
#  ('0_WA',
#   ('4_NP', '3_TSC', '0_P'),
#   1461,
#   0.09740649376625109,
#   0.842560553633218,
#   0.9850012271196131),
#  ('0_P',
#   ('1_WA', '0_L'),
#   1928,
#   0.12854190279351957,
#   0.964,
#   0.9849479564032697),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', 'low_SA', '0_P'),
#   1693,
#   0.11287419161277419,
#   0.8422885572139304,
#   0.984683247829442),
#  ('0_WA',
#   ('Soddisfatto_SAT', 'low_SA'),
#   1651,
#   0.11007400493366225,
#   0.8419173890872004,
#   0.9842493311706094),
#  ('0_WA',
#   ('163-184_AMH', '0_L', '0_P'),
#   1432,
#   0.0954730315354357,
#   0.8418577307466196,
#   0.9841795871760365),
#  ('0_WA',
#   ('163-184_AMH', '0_L'),
#   1462,
#   0.09747316487765852,
#   0.8416810592976396,
#   0.9839730481999451),
#  ('0_P',
#   ('Molto soddisfatto_SAT', 'medium_SA', '0_L'),
#   1571,
#   0.10474031602106808,
#   0.9626225490196079,
#   0.9835405730752792),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '3_TSC', '0_L'),
#   1399,
#   0.0932728848589906,
#   0.841250751653638,
#   0.983469994080508),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '3_TSC'),
#   1403,
#   0.0935395693046203,
#   0.8411270983213429,
#   0.9833254362994406),
#  ('0_WA',
#   ('4_NP', '3_TSC', '0_L', '0_P'),
#   1440,
#   0.09600640042669512,
#   0.840630472854641,
#   0.982744852871922),
#  ('0_P',
#   ('4_NP', 'medium_SA'),
#   1837,
#   0.12247483165544369,
#   0.9617801047120419,
#   0.9826798222463158),
#  ('0_P',
#   ('sales_D', 'medium_SA'),
#   1704,
#   0.11360757383825588,
#   0.9616252821670429,
#   0.9825216353694466),
#  ('0_WA',
#   ('4_NP', '3_TSC'),
#   1511,
#   0.10074004933662244,
#   0.8403781979977754,
#   0.9824499292103376),
#  ('0_WA',
#   ('Soddisfatto_SAT', '4_NP'),
#   1297,
#   0.08647243149543303,
#   0.8400259067357513,
#   0.9820380806804001),
#  ('0_WA',
#   ('Sufficiente_LE',),
#   2094,
#   0.13960930728715248,
#   0.8392785571142285,
#   0.9811643864502192),
#  ('0_WA',
#   ('sales_D', 'medium_SA'),
#   1487,
#   0.09913994266284419,
#   0.8391647855530474,
#   0.9810313810218362),
#  ('0_WA',
#   ('Sufficiente_LE', '0_P'),
#   2036,
#   0.1357423828255217,
#   0.8385502471169687,
#   0.9803129506241164),
#  ('0_WA',
#   ('4_TSC', '0_L', '0_P'),
#   1371,
#   0.09140609373958264,
#   0.8385321100917431,
#   0.9802917474096692),
#  ('0_WA',
#   ('4_NP', '3_TSC', '0_L'),
#   1487,
#   0.09913994266284419,
#   0.8382187147688839,
#   0.9799253704457124),
#  ('0_P',
#   ('4_NP', 'medium_SA', '0_L'),
#   1680,
#   0.11200746716447763,
#   0.958904109589041,
#   0.9797413310440073),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', 'medium_SA', '0_L', '0_P'),
#   1316,
#   0.08773918261217414,
#   0.8376830044557607,
#   0.9792990946088819),
#  ('0_WA',
#   ('Discreto_LE',),
#   1862,
#   0.12414160944062938,
#   0.8376068376068376,
#   0.9792100512287574),
#  ('0_WA',
#   ('229-250_AMH', '0_L', '0_P'),
#   1285,
#   0.08567237815854391,
#   0.8365885416666666,
#   0.9780196053358015),
#  ('0_WA',
#   ('Neutrale_SAT', '0_L', '0_P'),
#   2101,
#   0.14007600506700446,
#   0.8363853503184714,
#   0.977782063088601),
#  ('0_WA',
#   ('4_TSC', '0_L'),
#   1394,
#   0.09293952930195347,
#   0.8362327534493101,
#   0.9776036686661109),
#  ('0_WA',
#   ('4_NP', '0_L', '0_P'),
#   3211,
#   0.2140809387292486,
#   0.8355451470205568,
#   0.9767998176275395),
#  ('0_WA',
#   ('4_NP', 'low_SA', '0_P'),
#   1726,
#   0.11507433828921929,
#   0.8354307841239109,
#   0.9766661208943523),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', 'medium_SA', '0_L'),
#   1363,
#   0.09087272484832322,
#   0.835171568627451,
#   0.9763630832301744),
#  ('0_WA',
#   ('Buono_LE', '0_L', '0_P'),
#   2447,
#   0.16314420961397427,
#   0.8351535836177474,
#   0.9763420577305217),
#  ('0_WA',
#   ('3_TSC', 'medium_SA', '0_L', '0_P'),
#   1744,
#   0.11627441829455297,
#   0.8348492101483964,
#   0.9759862278266405),
#  ('0_WA',
#   ('Discreto_LE', '0_L'),
#   1807,
#   0.12047469831322088,
#   0.8346420323325635,
#   0.9757440251719501),
#  ('0_WA',
#   ('Soddisfatto_SAT', '0_P'),
#   3459,
#   0.23061537435829055,
#   0.8344993968636912,
#   0.9755772761931804),
#  ('0_WA',
#   ('medium_SA', '0_L', '0_P'),
#   4132,
#   0.27548503233548904,
#   0.8342418736119523,
#   0.9752762168593666),
#  ('0_WA',
#   ('4_NP', '0_L'),
#   3300,
#   0.22001466764450964,
#   0.8341759352881699,
#   0.975199131207113),
#  ('0_WA',
#   ('207-228_AMH', '0_P'),
#   1423,
#   0.09487299153276885,
#   0.8341148886283705,
#   0.975127764188381),
#  ('0_WA',
#   ('Discreto_LE', '0_P'),
#   1808,
#   0.12054136942462831,
#   0.8339483394833949,
#   0.9749330587616086),
#  ('0_WA',
#   ('229-250_AMH', '0_L'),
#   1318,
#   0.087872524834989,
#   0.8336495888678052,
#   0.974583802293703),
#  ('0_WA',
#   ('Soddisfatto_SAT', '3_TSC', '0_P'),
#   1433,
#   0.09553970264684312,
#   0.8336242001163467,
#   0.9745541213986816),
#  ('0_WA',
#   ('4_NP', 'low_SA'),
#   1739,
#   0.11594106273751584,
#   0.8332534738859607,
#   0.9741207213418179),
#  ('0_WA',
#   ('3_TSC', '0_L', '0_P'),
#   3946,
#   0.2630842056137076,
#   0.8328408611228366,
#   0.973638353544928),
#  ('0_WA',
#   ('3_TSC', 'medium_SA', '0_L'),
#   1802,
#   0.12014134275618374,
#   0.83271719038817,
#   0.9734937754194982),
#  ('0_WA',
#   ('3_TSC', 'low_SA', '0_L', '0_P'),
#   1830,
#   0.1220081338755917,
#   0.8325750682438581,
#   0.9733276265463466),
#  ('0_WA',
#   ('Soddisfatto_SAT',),
#   3527,
#   0.2351490099339956,
#   0.8320358575135646,
#   0.9726972585226776),
#  ('0_WA',
#   ('Soddisfatto_SAT', '3_TSC', '0_L', '0_P'),
#   1414,
#   0.09427295153010201,
#   0.831764705882353,
#   0.9723802668378341),
#  ('0_WA',
#   ('medium_SA', '0_L'),
#   4266,
#   0.2844189612640843,
#   0.8317410801325794,
#   0.9723526469920935),
#  ('0_WA',
#   ('Neutrale_SAT', '0_L'),
#   2155,
#   0.14367624508300553,
#   0.8317252026244694,
#   0.9723340852817159),
#  ('0_WA',
#   ('Soddisfatto_SAT', '3_TSC'),
#   1465,
#   0.09767317821188079,
#   0.8309699376063528,
#   0.9714511375025476),
#  ('0_WA',
#   ('3_TSC', '0_L'),
#   4036,
#   0.269084605640376,
#   0.8309656166357834,
#   0.9714460860420978),
#  ('0_WA',
#   ('207-228_AMH',),
#   1460,
#   0.09733982265484366,
#   0.8309618668184405,
#   0.9714417022922673),
#  ('0_WA',
#   ('Discreto_LE', '0_L', '0_P'),
#   1753,
#   0.11687445829721982,
#   0.8308056872037914,
#   0.9712591194364512),
#  ('0_WA',
#   ('3_TSC', 'low_SA', '0_L'),
#   1843,
#   0.12287485832388825,
#   0.8305543037404236,
#   0.9709652378645841),
#  ('0_WA',
#   ('3_NP', 'medium_SA', '0_P'),
#   1504,
#   0.10027335155677045,
#   0.830480397570403,
#   0.9708788373467245),
#  ('0_WA',
#   ('Buono_LE', '0_L'),
#   2494,
#   0.16627775185012333,
#   0.8302263648468708,
#   0.9705818586389879),
#  ('0_WA',
#   ('sales_D', '0_L', '0_P'),
#   2517,
#   0.16781118741249418,
#   0.8298714144411474,
#   0.9701669014187662),
#  ('0_WA',
#   ('3_NP', 'medium_SA'),
#   1540,
#   0.10267351156743783,
#   0.8297413793103449,
#   0.9700148829521327),
#  ('0_WA',
#   ('Soddisfatto_SAT', '3_TSC', '0_L'),
#   1443,
#   0.09620641376091739,
#   0.8288340034462952,
#   0.9689541089392816),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '0_L', '0_P'),
#   2940,
#   0.19601306753783584,
#   0.8284023668639053,
#   0.9684495012152545),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', '0_L'),
#   3021,
#   0.20141342756183744,
#   0.8283520701946806,
#   0.9683907015471561),
#  ('0_WA',
#   ('technical_D', '0_L', '0_P'),
#   1655,
#   0.11034068937929195,
#   0.8283283283283284,
#   0.9683629459545282),
#  ('0_WA',
#   ('2_TSC', '0_P'),
#   2642,
#   0.17614507633842255,
#   0.8282131661442006,
#   0.968228314808797),
#  ('0_WA',
#   ('2_TSC',),
#   2686,
#   0.17907860524034935,
#   0.8279901356350184,
#   0.9679675794535965),
#  ('0_WA',
#   ('technical_D', '0_L'),
#   1675,
#   0.1116741116074405,
#   0.8279782501235788,
#   0.9679536846144629),
#  ('0_WA',
#   ('3_NP', 'medium_SA', '0_L', '0_P'),
#   1472,
#   0.09813987599173278,
#   0.8274311410905003,
#   0.9673140830254414),
#  ('0_WA',
#   ('sales_D', '0_L'),
#   2585,
#   0.17234482298819923,
#   0.826935380678183,
#   0.9667345108957184),
#  ('0_WA',
#   ('3_NP', 'medium_SA', '0_L'),
#   1508,
#   0.10054003600240016,
#   0.8267543859649122,
#   0.9665229177776866),
#  ('0_WA',
#   ('0_L', '0_P'),
#   9200,
#   0.6133742249483299,
#   0.8267433501078361,
#   0.9665100162328475),
#  ('0_WA',
#   ('251-272_AMH', '0_L', '0_P'),
#   1279,
#   0.08527235149009935,
#   0.8262273901808785,
#   0.9659068297212001),
#  ('0_WA',
#   ('3_NP', '0_P'),
#   3271,
#   0.21808120541369425,
#   0.826010101010101,
#   0.9656528063172646),
#  ('0_WA',
#   ('2_TSC', '0_L', '0_P'),
#   2590,
#   0.17267817854523634,
#   0.8256295824035703,
#   0.9652079584155223),
#  ('0_WA',
#   ('2_TSC', '0_L'),
#   2634,
#   0.17561170744716315,
#   0.8254465684738327,
#   0.9649940047185516),
#  ('0_WA',
#   ('3_NP', '3_TSC', '0_P'),
#   1442,
#   0.09613974264950997,
#   0.8254149971379507,
#   0.964957096030563),
#  ('0_WA',
#   ('0_L',),
#   9428,
#   0.6285752383492232,
#   0.8249912495624782,
#   0.9644617110044902),
#  ('0_WA',
#   ('Sufficiente_LE', '0_L'),
#   1814,
#   0.12094139609307288,
#   0.8249204183719873,
#   0.9643789053126607),
#  ('0_WA',
#   ('3_NP',),
#   3345,
#   0.22301486765784387,
#   0.8249075215782984,
#   0.964363828227038),
#  ('0_WA',
#   ('3_NP', '3_TSC', '0_L', '0_P'),
#   1433,
#   0.09553970264684312,
#   0.8245109321058688,
#   0.9639001925686614),
#  ('0_WA',
#   ('Sufficiente_LE', '0_L', '0_P'),
#   1762,
#   0.11747449829988665,
#   0.8241347053320861,
#   0.9634603620635978),
#  ('0_WA',
#   ('207-228_AMH', '0_L', '0_P'),
#   1251,
#   0.08340556037069138,
#   0.8241106719367589,
#   0.9634322656570107),
#  ('0_WA',
#   ('Soddisfatto_SAT', 'medium_SA', '0_P'),
#   1499,
#   0.09993999599973331,
#   0.8240791643760308,
#   0.9633954315258056),
#  ('0_WA',
#   ('185-206_AMH', '0_P'),
#   1360,
#   0.09067271151410095,
#   0.8232445520581114,
#   0.9624197222384733),
#  ('0_WA',
#   ('3_NP', '3_TSC'),
#   1467,
#   0.09780652043469565,
#   0.8232323232323232,
#   0.9624054260453325),
#  ('0_WA',
#   ('185-206_AMH',),
#   1387,
#   0.09247283152210148,
#   0.8231454005934719,
#   0.9623038085348),
#  ('0_WA',
#   ('3_NP', '0_L', '0_P'),
#   3200,
#   0.2133475565037669,
#   0.823045267489712,
#   0.9621867472391418),
#  ('0_WA',
#   ('Ottimo_LE', '0_L', '0_P'),
#   1438,
#   0.09587305820388026,
#   0.8226544622425629,
#   0.9617298736692285),
#  ('0_WA',
#   ('3_NP', '3_TSC', '0_L'),
#   1458,
#   0.0972064804320288,
#   0.8223350253807107,
#   0.961356433802438),
#  ('0_WA',
#   ('3_NP', '0_L'),
#   3274,
#   0.21828121874791653,
#   0.8219934722570926,
#   0.9609571387672745),
#  ('0_WA',
#   ('Soddisfatto_SAT', 'medium_SA'),
#   1539,
#   0.1026068404560304,
#   0.8216764548852109,
#   0.9605865274219235),
#  ('0_WA',
#   ('251-272_AMH', '0_L'),
#   1312,
#   0.08747249816654444,
#   0.8215403882279274,
#   0.9604274577576526),
#  ('0_WA',
#   ('Soddisfatto_SAT', 'low_SA', '0_L', '0_P'),
#   1394,
#   0.09293952930195347,
#   0.8214496169711255,
#   0.9603213409937578),
#  ('0_WA',
#   ('185-206_AMH', '0_L', '0_P'),
#   1330,
#   0.08867257817187812,
#   0.8209876543209876,
#   0.9597812803710439),
#  ('0_WA',
#   ('185-206_AMH', '0_L'),
#   1357,
#   0.09047269817987866,
#   0.8209316394434362,
#   0.9597157957920576),
#  ('0_WA',
#   ('207-228_AMH', '0_L'),
#   1288,
#   0.08587239149276618,
#   0.8209050350541747,
#   0.9596846937472772),
#  ('0_WA',
#   ('4_NP', 'low_SA', '0_L', '0_P'),
#   1494,
#   0.09960664044269618,
#   0.8208791208791208,
#   0.9596543986021773),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', 'low_SA', '0_L'),
#   1382,
#   0.09213947596506433,
#   0.8206650831353919,
#   0.9594041763014609),
#  ('0_WA',
#   ('Soddisfatto_SAT', '0_L', '0_P'),
#   3077,
#   0.20514700980065337,
#   0.8205333333333333,
#   0.9592501532865679),
#  ('0_WA',
#   ('3_NP', 'low_SA', '0_P'),
#   1448,
#   0.09653976931795454,
#   0.8199320498301246,
#   0.958547218659551),
#  ('0_WA',
#   ('5_NP', '0_L'),
#   1762,
#   0.11747449829988665,
#   0.8199162401116799,
#   0.9585287361991494),
#  ('0_WA',
#   ('3_NP', 'low_SA'),
#   1468,
#   0.09787319154610308,
#   0.8196538246789503,
#   0.9582219576274026),
#  ('0_WA',
#   ('Ottimo_LE', '0_L'),
#   1476,
#   0.0984065604373625,
#   0.8195446973903387,
#   0.9580943816179026),
#  ('0_WA',
#   ('5_NP', '0_L', '0_P'),
#   1720,
#   0.11467431162077472,
#   0.8194378275369223,
#   0.9579694446785891),
#  ('0_WA',
#   ('Molto soddisfatto_SAT', 'low_SA', '0_L', '0_P'),
#   1365,
#   0.09100606707113808,
#   0.819327731092437,
#   0.9578407356707297),
#  ('0_WA',
#   ('Soddisfatto_SAT', 'low_SA', '0_L'),
#   1399,
#   0.0932728848589906,
#   0.8190866510538641,
#   0.9575588993886912),
#  ('0_WA',
#   ('4_NP', 'low_SA', '0_L'),
#   1504,
#   0.10027335155677045,
#   0.8182807399347116,
#   0.9566167434357552),
#  ('0_WA',
#   ('Soddisfatto_SAT', '0_L'),
#   3142,
#   0.20948063204213616,
#   0.8180161416297839,
#   0.956307412962208),
#  ('0_WA',
#   ('Insufficiente_LE', '0_L', '0_P'),
#   1800,
#   0.1200080005333689,
#   0.8174386920980926,
#   0.9556323416039978),
#  ('0_WA',
#   ('low_SA', '0_L', '0_P'),
#   4162,
#   0.27748516567771186,
#   0.8173605655930872,
#   0.9555410072744127),
#  ('0_WA',
#   ('Soddisfatto_SAT', 'medium_SA', '0_L', '0_P'),
#   1375,
#   0.09167277818521234,
#   0.8169934640522876,
#   0.9551118446859128),
#  ('0_WA',
#   ('3_NP', 'low_SA', '0_L', '0_P'),
#   1412,
#   0.09413960930728715,
#   0.816657027183343,
#   0.9547185308435667),
#  ('0_WA',
#   ('3_NP', 'low_SA', '0_L'),
#   1432,
#   0.0954730315354357,
#   0.8164196123147093,
#   0.9544409793537275),
#  ('0_WA',
#   ('low_SA', '0_L'),
#   4199,
#   0.27995199679978666,
#   0.8162908242612753,
#   0.954290418791494),
#  ('0_WA',
#   ('Soddisfatto_SAT', 'medium_SA', '0_L'),
#   1415,
#   0.09433962264150944,
#   0.8146229130685089,
#   0.9523405357065132),
#  ('0_WA',
#   ('2_TSC', 'low_SA'),
#   1242,
#   0.08280552036802453,
#   0.8133595284872298,
#   0.9508635672470741),
#  ('0_WA',
#   ('Insufficiente_LE', '0_L'),
#   1837,
#   0.12247483165544369,
#   0.8131916777335104,
#   0.9506673401656214),
#  ('0_WA',
#   ('2_TSC', 'low_SA', '0_P'),
#   1235,
#   0.08233882258817254,
#   0.8130348913759052,
#   0.9504840479927671),
#  ('0_WA',
#   ('support_D', '0_L', '0_P'),
#   1347,
#   0.0898059870658044,
#   0.8129149064574532,
#   0.9503437787962074),
#  ('0_WA',
#   ('support_D', '0_L'),
#   1360,
#   0.09067271151410095,
#   0.8124253285543608,
#   0.94977143437154),
#  ('0_WA',
#   ('141-162_AMH', '0_L'),
#   1389,
#   0.09260617374491632,
#   0.8108581436077058,
#   0.9479393059993748),
#  ('0_WA',
#   ('141-162_AMH', '0_L', '0_P'),
#   1354,
#   0.09027268484565637,
#   0.8107784431137725,
#   0.9478461315871763),
#  ('0_WA',
#   ('2_TSC', 'low_SA', '0_L'),
#   1220,
#   0.08133875591706113,
#   0.8106312292358804,
#   0.9476740301877608)]

# %%
interesting_rules = list()
min_lift = 1.1
for rule in rules:
    if rule[5] > min_lift:
        interesting_rules.append(rule)
len(interesting_rules)
# Out:
# 109

# %%
rules_left = list()
rules_not_left = list()
for rule in rules:
    if rule[0] == '1_L':
        rules_left.append(rule)
    elif rule[0] == '0_L':
        rules_not_left.append(rule)
len(rules_left), len(rules_not_left)
# Out:
# (6, 83)

# %%
min_lift = 1.0
interesting_left_rules = list()
interesting_not_left_rules = list()

for rule in rules_left:
    if rule[5] > min_lift:
        interesting_left_rules.append(rule)
for rule in rules_not_left:
    if rule[5] > min_lift:
        interesting_not_left_rules.append(rule)    
        
len(interesting_left_rules), len(interesting_not_left_rules)
# Out:
# (6, 83)

# %%
interesting_left_rules.sort(key=lambda rule: rule[5], reverse=True)
for int_rule in interesting_left_rules:
    print int_rule
# Out:
# ('1_L', ('2_NP', '3_TSC', '0_WA', '0_P'), 1446, 0.09640642709513968, 0.8431486880466472, 3.5414133777685977)
# ('1_L', ('2_NP', 'Insufficiente_LE', '0_P'), 1292, 0.0861390759383959, 0.8427919112850619, 3.5399148354423535)
# ('1_L', ('2_NP', '3_TSC', '0_WA'), 1455, 0.09700646709780653, 0.842501447596989, 3.5386948228807724)
# ('1_L', ('2_NP', 'Insufficiente_LE'), 1301, 0.08673911594106273, 0.8350449293966624, 3.5073757759788684)
# ('1_L', ('2_NP', '3_TSC', '0_P'), 1516, 0.10107340489365958, 0.8243610657966286, 3.4625011553860636)
# ('1_L', ('2_NP', '3_TSC'), 1528, 0.1018734582305487, 0.8241639697950378, 3.461673308024579)

# %%
interesting_not_left_rules.sort(key=lambda rule: rule[2], reverse=True)
for int_rule in interesting_not_left_rules:
    print int_rule
# Out:
# ('0_L', ('3_NP',), 3983, 0.2655510367357824, 0.9822441430332922, 1.2891739500661838)
# ('0_L', ('4_NP',), 3956, 0.26375091672778184, 0.9063001145475372, 1.1894990740373215)
# ('0_L', ('3_NP', '0_P'), 3888, 0.2592172811520768, 0.9818181818181818, 1.288614885289719)
# ('0_L', ('4_NP', '0_P'), 3843, 0.2562170811387426, 0.9046610169491526, 1.1873477942964945)
# ('0_L', ('Soddisfatto_SAT',), 3841, 0.2560837389159277, 0.9061099315876386, 1.189249463062915)
# ('0_L', ('Soddisfatto_SAT', '0_P'), 3750, 0.25001666777785186, 0.9047044632086851, 1.1874048165616966)
# ('0_L', ('Molto soddisfatto_SAT',), 3647, 0.24314954330288685, 0.8633996212121212, 1.1331931150298045)
# ('0_L', ('Molto soddisfatto_SAT', '0_P'), 3549, 0.236615774384959, 0.8603636363636363, 1.1292084513316576)
# ('0_L', ('4_NP', '0_WA'), 3300, 0.22001466764450964, 0.8962520369364476, 1.1763111919854548)
# ('0_L', ('3_NP', '0_WA'), 3274, 0.21828121874791653, 0.9787742899850523, 1.2846198438471998)
# ('0_L', ('4_NP', '0_WA', '0_P'), 3211, 0.2140809387292486, 0.8944289693593315, 1.1739184556720872)
# ('0_L', ('3_NP', '0_WA', '0_P'), 3200, 0.2133475565037669, 0.9782940996637114, 1.2839896045551284)
# ('0_L', ('2_TSC',), 3191, 0.21274751650110008, 0.9836621454993835, 1.2910350472825738)
# ('0_L', ('Soddisfatto_SAT', '0_WA'), 3142, 0.20948063204213616, 0.8908420754182025, 1.1692107358415837)
# ('0_L', ('2_TSC', '0_P'), 3137, 0.209147276485099, 0.983385579937304, 1.2906720610325186)
# ('0_L', ('Soddisfatto_SAT', '0_WA', '0_P'), 3077, 0.20514700980065337, 0.8895634576467187, 1.1675325779876735)
# ('0_L', ('Molto soddisfatto_SAT', '0_WA'), 3021, 0.20141342756183744, 0.8476430976430976, 1.1125130225366486)
# ('0_L', ('Molto soddisfatto_SAT', '0_WA', '0_P'), 2940, 0.19601306753783584, 0.8440999138673557, 1.107862671342008)
# ('0_L', ('2_TSC', '0_WA'), 2634, 0.17561170744716315, 0.9806403574087863, 1.2870690165185847)
# ('0_L', ('2_TSC', '0_WA', '0_P'), 2590, 0.17267817854523634, 0.9803179409538229, 1.2866458519746578)
# ('0_L', ('Sufficiente_LE',), 2199, 0.14660977398493233, 0.8813627254509018, 1.1567692963806506)
# ('0_L', ('Discreto_LE',), 2165, 0.14434295619707982, 0.9739091318038686, 1.278234430165053)
# ('0_L', ('Sufficiente_LE', '0_P'), 2138, 0.14254283618907926, 0.8805601317957167, 1.1557159097658343)
# ('0_L', ('Discreto_LE', '0_P'), 2110, 0.14067604506967132, 0.9732472324723247, 1.2773657017721736)
# ('0_L', ('1_WA',), 2000, 0.13334222281485433, 0.9220839096357769, 1.2102149598028542)
# ('0_L', ('1_WA', '0_P'), 1928, 0.12854190279351957, 0.9211657907310081, 1.2090099488252004)
# ('0_L', ('4_NP', 'low_SA'), 1838, 0.12254150276685112, 0.8806899856252994, 1.1558863400764672)
# ('0_L', ('3_NP', 'medium_SA'), 1824, 0.12160810720714714, 0.9827586206896551, 1.2898491907353988)
# ('0_L', ('4_NP', 'low_SA', '0_P'), 1820, 0.12134142276151744, 0.8809293320425944, 1.1562004770132022)
# ('0_L', ('Sufficiente_LE', '0_WA'), 1814, 0.12094139609307288, 0.8662846227316141, 1.136979616411575)
# ('0_L', ('Discreto_LE', '0_WA'), 1807, 0.12047469831322088, 0.9704618689581096, 1.2737099730926396)
# ('0_L', ('3_NP', 'medium_SA', '0_P'), 1779, 0.11860790719381292, 0.9823302043070127, 1.2892869036052577)
# ('0_L', ('4_NP', '3_TSC'), 1774, 0.11827455163677579, 0.9866518353726362, 1.294958949838482)
# ('0_L', ('3_NP', '3_TSC'), 1773, 0.11820788052536836, 0.9949494949494949, 1.3058494465127297)
# ('0_L', ('Sufficiente_LE', '0_WA', '0_P'), 1762, 0.11747449829988665, 0.8654223968565815, 1.135847963812729)
# ('0_L', ('3_NP', 'low_SA'), 1754, 0.11694112940862725, 0.9793411501954216, 1.2853638354726222)
# ('0_L', ('Discreto_LE', '0_WA', '0_P'), 1753, 0.11687445829721982, 0.9695796460176991, 1.2725520747829426)
# ('0_L', ('4_NP', 'medium_SA'), 1752, 0.11680778718581239, 0.9172774869109948, 1.203906635122332)
# ('0_L', ('Soddisfatto_SAT', '3_TSC'), 1741, 0.11607440496033068, 0.9875212705615428, 1.296100064504076)
# ('0_L', ('3_NP', '3_TSC', '0_P'), 1738, 0.11587439162610841, 0.994848311390956, 1.3057166453056481)
# ('0_L', ('163-184_AMH',), 1737, 0.11580772051470098, 0.9769403824521935, 1.2822128803290558)
# ('0_L', ('Soddisfatto_SAT', 'medium_SA'), 1737, 0.11580772051470098, 0.9273892151628403, 1.2171780572477635)
# ('0_L', ('3_NP', 'low_SA', '0_P'), 1729, 0.11527435162344156, 0.9790486976217441, 1.2849799978673906)
# ('0_L', ('4_NP', '3_TSC', '0_P'), 1713, 0.11420761384092273, 0.9878892733564014, 1.2965830601218642)
# ('0_L', ('Soddisfatto_SAT', 'low_SA'), 1708, 0.11387425828388559, 0.8709841917389087, 1.143147697925437)
# ('0_L', ('163-184_AMH', '0_P'), 1701, 0.1134075605040336, 0.9764638346727899, 1.2815874217935925)
# ('0_L', ('Soddisfatto_SAT', '3_TSC', '0_P'), 1700, 0.11334088939262618, 0.9889470622454916, 1.2979713848985062)
# ('0_L', ('Soddisfatto_SAT', 'low_SA', '0_P'), 1697, 0.1131408760584039, 0.8715973292244479, 1.1439524274621538)
# ('0_L', ('Molto soddisfatto_SAT', 'low_SA'), 1684, 0.11227415161010734, 0.8303747534516766, 1.0898486985493259)
# ('0_L', ('Soddisfatto_SAT', 'medium_SA', '0_P'), 1683, 0.11220748049869991, 0.9252336448598131, 1.2143489183804985)
# ('0_L', ('4_NP', 'medium_SA', '0_P'), 1680, 0.11200746716447763, 0.914534567229178, 1.2003066130443159)
# ('0_L', ('Molto soddisfatto_SAT', 'low_SA', '0_P'), 1666, 0.11107407160477366, 0.8288557213930349, 1.0878550022028464)
# ('0_L', ('Molto soddisfatto_SAT', '3_TSC'), 1663, 0.11087405827055137, 0.9970023980815348, 1.3085438369640305)
# ('0_L', ('185-206_AMH',), 1653, 0.11020734715647709, 0.9810089020771513, 1.287552723333496)
# ('0_L', ('Molto soddisfatto_SAT', 'medium_SA'), 1632, 0.10880725381692113, 0.8793103448275862, 1.15407559171062)
# ('0_L', ('185-206_AMH', '0_P'), 1620, 0.108007200480032, 0.9806295399515739, 1.287054818842637)
# ('0_L', ('Molto soddisfatto_SAT', '3_TSC', '0_P'), 1613, 0.10754050270018001, 0.9969097651421508, 1.3084222582575358)
# ('0_L', ('Molto soddisfatto_SAT', 'medium_SA', '0_P'), 1571, 0.10474031602106808, 0.8756967670011149, 1.1493328498643438)
# ('0_L', ('207-228_AMH',), 1569, 0.10460697379825322, 0.8929994308480365, 1.172042217648731)
# ('0_L', ('207-228_AMH', '0_P'), 1518, 0.10120674711647443, 0.8898007033997656, 1.1678439578485371)
# ('0_L', ('3_NP', 'medium_SA', '0_WA'), 1508, 0.10054003600240016, 0.9792207792207792, 1.285205851201651)
# ('0_L', ('2_TSC', 'low_SA'), 1505, 0.10034002266817788, 0.9855926653569089, 1.2935688123633424)
# ('0_L', ('4_NP', 'low_SA', '0_WA'), 1504, 0.10027335155677045, 0.8648648648648649, 1.135116215270223)
# ('0_L', ('2_TSC', 'low_SA', '0_P'), 1497, 0.09980665377691846, 0.9855167873601053, 1.293469224152452)
# ('0_L', ('4_NP', 'low_SA', '0_WA', '0_P'), 1494, 0.09960664044269618, 0.86558516801854, 1.1360615974020023)
# ('0_L', ('4_NP', '3_TSC', '0_WA'), 1487, 0.09913994266284419, 0.9841164791528789, 1.2916313502637409)
# ('0_L', ('4_NP', 'medium_SA', '0_WA'), 1481, 0.09873991599439963, 0.9108241082410824, 1.1954367167927893)
# ('0_L', ('3_NP', 'medium_SA', '0_WA', '0_P'), 1472, 0.09813987599173278, 0.9787234042553191, 1.284553057440106)
# ('0_L', ('sales_D', 'medium_SA'), 1469, 0.0979398626575105, 0.8290067720090294, 1.0880532528319418)
# ('0_L', ('163-184_AMH', '0_WA'), 1462, 0.09747316487765852, 0.9727212242182302, 1.2766753274456804)
# ('0_L', ('4_NP', 'medium_SA', '0_WA', '0_P'), 1424, 0.09493966264417628, 0.9075844486934354, 1.1911847345075985)
# ('0_L', ('Soddisfatto_SAT', 'medium_SA', '0_WA'), 1415, 0.09433962264150944, 0.9194282001299545, 1.2067293991730126)
# ('0_L', ('Soddisfatto_SAT', '4_NP'), 1414, 0.09427295153010201, 0.9158031088082902, 1.201971546116166)
# ('0_L', ('sales_D', 'medium_SA', '0_P'), 1402, 0.09347289819321287, 0.8227699530516432, 1.079867564387609)
# ('0_L', ('Soddisfatto_SAT', 'low_SA', '0_WA'), 1399, 0.0932728848589906, 0.8473652331920049, 1.1121483315231782)
# ('0_L', ('Soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1394, 0.09293952930195347, 0.8484479610468655, 1.1135693881468267)
# ('0_L', ('Molto soddisfatto_SAT', 'low_SA', '0_WA'), 1382, 0.09213947596506433, 0.808187134502924, 1.0607279340575215)
# ('0_L', ('Soddisfatto_SAT', '4_NP', '0_P'), 1373, 0.0915394359623975, 0.9153333333333333, 1.2013549760821374)
# ('0_L', ('Molto soddisfatto_SAT', 'low_SA', '0_WA', '0_P'), 1365, 0.09100606707113808, 0.8062610750147667, 1.0582000231139732)
# ('0_L', ('Molto soddisfatto_SAT', 'medium_SA', '0_WA'), 1363, 0.09087272484832322, 0.868706182281708, 1.1401578603468097)
# ('0_L', ('Molto soddisfatto_SAT', '4_NP'), 1361, 0.09073938262550836, 0.8630310716550412, 1.1327094017985617)
# ('0_L', ('Molto soddisfatto_SAT', '4_NP', '0_P'), 1320, 0.08800586705780386, 0.8599348534201955, 1.1286456830984872)
# ('0_L', ('Molto soddisfatto_SAT', 'medium_SA', '0_WA', '0_P'), 1316, 0.08773918261217414, 0.8646517739816032, 1.134836538147538)

# %%
first_int_rule = interesting_left_rules[0]
first_int_rule
# Out:
# ('1_L',
#  ('2_NP', '3_TSC', '0_WA', '0_P'),
#  1446,
#  0.09640642709513968,
#  0.8431486880466472,
#  3.5414133777685977)

# %%
hr_baskets_list[0]
# Out:
# ['Insoddisfatto_SAT',
#  'Insufficiente_LE',
#  '2_NP',
#  '141-162_AMH',
#  '3_TSC',
#  '0_WA',
#  '1_L',
#  '0_P',
#  'sales_D',
#  'low_SA']

# %%
from __future__ import division

# %%
counter = 0
c_left = 0
c_not_left = 0
for row in hr_baskets_list:
    if '2_NP' in row and '3_TSC' in row:
        counter += 1
    if '2_NP' in row and '3_TSC' in row and '1_L' in row:
        c_left += 1
    if '2_NP' in row and '3_TSC' in row and '0_L' in row:
        c_not_left += 1
accuracy = (c_left/counter) * 100
print 'counter', counter
print 'c_left', c_left
print 'c_not_left', c_not_left
print 'accuracy', accuracy
# Out:
# counter 1854
# c_left 1528
# c_not_left 326
# accuracy 82.4163969795

# %%
counter = 0
c_left = 0
c_not_left = 0
for row in hr_baskets_list:
    if '3_NP' in row:
        counter += 1
    if '3_NP' in row and '1_L' in row:
        c_left += 1
    if '3_NP' in row and '0_L' in row:
        c_not_left += 1
accuracy = (c_not_left/counter) * 100
print 'counter', counter
print 'c_left', c_left
print 'c_not_left', c_not_left
print 'accuracy', accuracy
# Out:
# counter 4055
# c_left 72
# c_not_left 3983
# accuracy 98.2244143033
